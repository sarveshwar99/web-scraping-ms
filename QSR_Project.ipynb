# %%
import builtwith
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
builtwith.parse('https://www.netleaseadvisor.com')
# Out:
# {'web-servers': ['Nginx'],
#  'font-scripts': ['Google Font API'],
#  'analytics': ['TrackJs'],
#  'web-frameworks': ['Twitter Bootstrap'],
#  'cms': ['WordPress'],
#  'programming-languages': ['PHP'],
#  'blogs': ['PHP', 'WordPress'],
#  'javascript-frameworks': ['jQuery', 'jQuery UI']}

# %%
html=uReq('https://www.netleaseadvisor.com/tenant/popeyes/')

# %%
soup=BeautifulSoup(html,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Popeye’s | Net Lease Advisor
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php" rel="pingback"/>
#   <script type="text/javascript">
#    var ajaxurl = 'https://www.netleaseadvisor.com/wp-admin/admin-ajax.php';
#   </script>
#   <!-- All in One SEO Pack 2.7.3 by Michael Torbert of Semper Fi Web Design[-1,-1] -->
#   <link href="https://www.netleaseadvisor.com/tenant/popeyes/" rel="canonical"/>
#   <!-- /all in one seo pack -->
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://www.netleaseadvisor.com/feed/" rel="alternate" title="Net Lease Advisor » Feed" type="application/rss+xml"/>
#   <link href="https://www.netleaseadvisor.com/comments/feed/" rel="alternate" title="Net Lease Advisor » Comments Feed" type="application/rss+xml"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.netleaseadvisor.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.css?ver=4.9.8" id="jquery-ui-timepicker-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/css/dsc-style.css?ver=4.9.8" id="dsc-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/css/settings.css?ver=5.3.0.2" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="rs-plugin-settings-inline-css" type="text/css">
#    #rs-demo-id {}
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.6-78496d1" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=4.9.8" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/bootstrap.min.css?ver=4.9.8" id="lambda-bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/theme.min.css?ver=4.9.8" id="lambda-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda-child-theme/style.css?ver=4.9.8" id="lambda-child-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/lambda/stack-90.css?ver=4.9.8" id="lambda-theme-stack-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/css/wpb_wmca_style.css?ver=1.0" id="wpb_wmca_accordion_style-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="//www.google.com/jsapi?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/js/dynamic-stock-charts.min.js?ver=1.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.tools.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.revolution.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var mejsL10n = {"language":"en","strings":{"mejs.install-flash":"You are using a browser that does not have Flash player enabled or installed. Please turn on your Flash player plugin or download the latest version from https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen-off":"Turn off Fullscreen","mejs.fullscreen-on":"Go Fullscreen","mejs.download-video":"Download Video","mejs.fullscreen":"Fullscreen","mejs.time-jump-forward":["Jump forward 1 second","Jump forward %1 seconds"],"mejs.loop":"Toggle Loop","mejs.play":"Play","mejs.pause":"Pause","mejs.close":"Close","mejs.time-slider":"Time Slider","mejs.time-help-text":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.","mejs.time-skip-back":["Skip back 1 second","Skip back %1 seconds"],"mejs.captions-subtitles":"Captions\/Subtitles","mejs.captions-chapters":"Chapters","mejs.none":"None","mejs.mute-toggle":"Mute Toggle","mejs.volume-help-text":"Use Up\/Down Arrow keys to increase or decrease volume.","mejs.unmute":"Unmute","mejs.mute":"Mute","mejs.volume-slider":"Volume Slider","mejs.video-player":"Video Player","mejs.audio-player":"Audio Player","mejs.ad-skip":"Skip ad","mejs.ad-skip-info":["Skip in 1 second","Skip in %1 seconds"],"mejs.source-chooser":"Source Chooser","mejs.stop":"Stop","mejs.speed-rate":"Speed Rate","mejs.live-broadcast":"Live Broadcast","mejs.afrikaans":"Afrikaans","mejs.albanian":"Albanian","mejs.arabic":"Arabic","mejs.belarusian":"Belarusian","mejs.bulgarian":"Bulgarian","mejs.catalan":"Catalan","mejs.chinese":"Chinese","mejs.chinese-simplified":"Chinese (Simplified)","mejs.chinese-traditional":"Chinese (Traditional)","mejs.croatian":"Croatian","mejs.czech":"Czech","mejs.danish":"Danish","mejs.dutch":"Dutch","mejs.english":"English","mejs.estonian":"Estonian","mejs.filipino":"Filipino","mejs.finnish":"Finnish","mejs.french":"French","mejs.galician":"Galician","mejs.german":"German","mejs.greek":"Greek","mejs.haitian-creole":"Haitian Creole","mejs.hebrew":"Hebrew","mejs.hindi":"Hindi","mejs.hungarian":"Hungarian","mejs.icelandic":"Icelandic","mejs.indonesian":"Indonesian","mejs.irish":"Irish","mejs.italian":"Italian","mejs.japanese":"Japanese","mejs.korean":"Korean","mejs.latvian":"Latvian","mejs.lithuanian":"Lithuanian","mejs.macedonian":"Macedonian","mejs.malay":"Malay","mejs.maltese":"Maltese","mejs.norwegian":"Norwegian","mejs.persian":"Persian","mejs.polish":"Polish","mejs.portuguese":"Portuguese","mejs.romanian":"Romanian","mejs.russian":"Russian","mejs.serbian":"Serbian","mejs.slovak":"Slovak","mejs.slovenian":"Slovenian","mejs.spanish":"Spanish","mejs.swahili":"Swahili","mejs.swedish":"Swedish","mejs.tagalog":"Tagalog","mejs.thai":"Thai","mejs.turkish":"Turkish","mejs.ukrainian":"Ukrainian","mejs.vietnamese":"Vietnamese","mejs.welsh":"Welsh","mejs.yiddish":"Yiddish"}};
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.6-78496d1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/Chart.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <link href="https://www.netleaseadvisor.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <link href="https://www.netleaseadvisor.com/tenant/pollo-tropical/" rel="prev" title="Pollo Tropical"/>
#   <meta content="WordPress 4.9.8" name="generator"/>
#   <link href="https://www.netleaseadvisor.com/?p=1259" rel="shortlink"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fpopeyes%2F" rel="alternate" type="application/json+oembed"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fpopeyes%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#   <!-- This site is using AdRotate v4.14 Professional to display their advertisements - https://ajdg.solutions/products/adrotate-for-wordpress/ -->
#   <style type="text/css">
#    .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#   </style>
#   <meta content="Powered by Visual Composer - drag and drop page builder for WordPress." name="generator"/>
#   <!--[if lte IE 9]><link rel="stylesheet" type="text/css" href="https://www.netleaseadvisor.com/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css" media="screen"><![endif]-->
#   <!--[if lte IE 8]><script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/excanvas.compiled.js"></script><![endif]-->
#   <style>
#    /*wp_charts_js responsive canvas CSS override*/
#     			.wp_charts_canvas {
#     				width:100%!important;
#     				max-width:100%;
#     			}
#
#     			@media screen and (max-width:480px) {
#     				div.wp-chart-wrap {
#     					width:100%!important;
#     					float: none!important;
# 						margin-left: auto!important;
# 						margin-right: auto!important;
# 						text-align: center;
#     				}
#     			}
#   </style>
#   <meta content="Powered by Slider Revolution 5.3.0.2 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-150x150.png" rel="icon" sizes="32x32"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="icon" sizes="192x192"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" name="msapplication-TileImage"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto:100,300,300italic,400,400italic,500,700,700italic%7CRoboto+Condensed:300,400,700%7CCutive:400%7CRoboto+Slab:100,300,400,700&amp;subset=latin,latin,latin,latin" rel="stylesheet" type="text/css"/>
#   <style media="screen" type="text/css">
#    .tenant-news-title {
#     font-family: Roboto, sans-serif;
#     font-weight: bold;
#     line-height: 18px;
#     margin-bottom: -4px;
# }
# span.tenant-news-date {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# span.tenant-news-source {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# .eh-section {
#   margin-top: -15px;
# }
# .eh-title {
#     font-size: 18px;
#     font-weight: bold;
#     color: #FF6D00;
#     margin-top: -5px;
#     margin-bottom: 11px;
#     line-height: 20px;
# }
# .eh-bullets {
#  padding-bottom: 10px;
# }
# .eh-buttons a i {
#     margin-left: 0px !important;
#     padding-right: 5px !important;
#     font-size: 18px;
#     position: relative;
#     top: 1px;
# }
#
# .eh-buttons a {
# background: #9c0 !important;
# font-weight: bold;
# margin-top: -3px;
# }
# .eh-buttons a:hover {
# background: #ff6d00 !important;
# }
#
# /* Sidebar Contact Us button hover fix */
# .sidebar-contact-btn.btn.btn-block.btn-success:hover {
#     background-color: #ff6d00 !important;
# }
# /* SCUBHF END */
#
# /* Sector Button Hover Fix */
# .selector-buttons:hover {
#     background-color: #ff6d00;
# }
# /* SBHF END */
#
# /* Credit Rating Nav item fix */
# .menu-item-523.active a:hover, .current-menu-item.menu-item-523 a:hover {
#     color: #0a2341 !important;
# }
# .menu-item-523.active a, .current-menu-item.menu-item-523 a{
#     color: #FFFFFF !important;
# }
# /* CRNIF END */
# .powered-by {
#   margin-top: -15px;
# }
#
# .dsc-loader {
#
#     position: relative !important;
#     top: 140px !important;
#
# }
#
# .wpcf7-mail-sent-ok {
#  color: #07182d !important;
#  font-weight: bold !important;
# font-size: 18px !important;
# }
#
# .btn {
#   border-radius: 5px !important;
# }
#
# .tenant-snapshot {
# 	color: #9c0;
# 	font-size: 22px;
#         line-height: 38px;
# 	margin-top: 4px;
# 	margin-bottom: -1px;
#
# }
#
# .tenant-snapshot .tenant-name {
# 	color: #0a2341;
# 	font-size: 40px;
# 	/* position: relative;
#         top: 6px; */
# }
#
# @media (max-width: 700px) {
#
# .tenant-logo {
#     height: 75px !important;
#     width: 100% !important;
#     margin-bottom: 25px !important;
# }
# .tenant-logo img {
#     position: inherit !important;
# }
#
# }
#
# /* Stock Chart Tooltip Style */
# .google-visualization-tooltip .dsc-tooltip caption {
#     font-size: 18px;
#     padding: 0;
# }
# .google-visualization-tooltip .dsc-tooltip td.label {
#     width: auto;
#     color: #FF6D00;
#     text-align: right;
#     padding-right: 5px;
# }
#
# /* Site Width Settings */
# @media (min-width: 1200px) and (max-width: 1414px){
#      .container {
#         width: 1200px !important;
#     }
#
# .featured-thumb a img {
#     width: 65px;
# }
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 17px;
#     font-weight: bold;
#     color: #84919F;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-desc {
#     float: left;
#     margin-left: 10px;
#     line-height: 18px;
# }
# }
#
# @media (min-width: 1415px){
#     .container {
#         width: 1400px !important;
#     }
# }
# @media (min-width: 768px){
#     .container {
#         width: 100%;
#     }
# }
# a.tenant-detail-link.btn.btn-success, .sidebar-contact-btn {
#     background: #9c0 !important;
#     border-radius: 5px !important;
#     font-size: 20px;
#     padding: 7px 30px;
#     margin: 20px auto;
#     font-weight: bold;
#     text-transform: uppercase;
# }
# a.tenant-detail-link.btn.btn-success:hover, .sidebar-contact-btn:hover {
#     background-color: #83ad04 !important;
# }
# .table-striped > tbody > tr:nth-child(odd) > td, .table-striped > tbody > tr:nth-child(odd) > th, .table-hover > tbody > tr:hover > td, .table-hover > tbody > tr:hover > th {
#     background: rgb(243, 243, 243);
# }
#
# section.section.tenant > .container > .row {
#     padding-bottom: 30px;
# }
#
# /* HOMEPAGE FEATURED TENANTS */
#
# .featured-single-wrapper {
#     width: 100%;
#     margin-top: 10px;
#     margin-bottom: 10px;
# }
#
# .featured-thumb {
#     float: left;
# }
#
# .featured-thumb a img {
#     width: 65px;
# }
#
# .featured-desc {
#     float: left;
#     margin-left: 15px;
#     line-height: 18px;
# }
#
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 20px;
#     font-weight: bold;
#     color: #84919F;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-tenants > .post-title {
#     padding-top: 30px;
# }
#
# .featured-sector, .featured-cap {
#     font-size: 14px;
# }
#
# .featured-sector span, .featured-cap span {
#     font-weight: bold;
# }
#
# /* HEADER TAGLINE */
#
# .tagline {
# 	font-family: "Roboto Condensed" !important;
# 	font-weight: bold !important;
# 	font-size: 20px !important;
# 	color: #fff !important;
#         text-align: right !important;
# }
#
# /* SIDEBAR ACCORDION */
#
# .selector-buttons {
#     width: 100%;
#     margin: 30px 0;
#     padding: 10px;
#     font-size: 18px;
#     font-weight: bold;
#     background-color: #9c0;
# }
#
# @media (min-width: 992px) and (max-width: 1199px){
#
#     .selector-buttons {
#         font-size: 16px;
#         padding: 10px 5px;
#     }
#
# }
#
# .sidebar-toggle {
#     display:none;
# }
#
# @media (max-width: 991px) {
#     .col-md-3.sidebar .sidebar-collapse-control-btn {
#         position: absolute;
#         top: -1px;
#         left: -55px;
#         width: 55px;
#         height: 45px;
#         background-color: #9c0;
#         border-top-left-radius: 5px;
#         border-bottom-left-radius: 5px;
#     }
#     .sidebar-collapse-control-btn button.navbar-toggle.collapsed {
#         margin: 14px 15px;
#     }
#     .col-md-3.sidebar {
#         position: absolute;
#         top: -65px;
#         right: -300px;
#         width: 300px;
#         background-color: #f3f3f3;
#         border: 1px solid #9c0;
#     }
#
#
# .sidebar-toggle {
#     display: block;
#     background: none !important;
#     margin: 14px 17px;
#     width: 22px;
#     height: 16px;
#     border: none;
#     transform: translate3d(0,0,0);
# }
#
# .sidebar-toggle .icon-bar:nth-child(1) {
#     top: 0;
# }
#
# .sidebar-toggle .icon-bar {
#     background-color: #fff;
# }
#
# .sidebar-toggle .icon-bar {
#     height: 1px;
#     width: 100%;
#     position: absolute;
#     left: 0;
#     margin-top: 0!important;
#     transition: all .3s;
#     -ms-transform-origin: 50% 50% 50%;
#     transform-origin: 50% 50% 50%;
#     transform: translate3d(0,0,0);
#     box-shadow: none;
# }
#
# .sidebar-toggle .icon-bar {
#     display: block;
#     width: 22px;
#     height: 1px;
#     border-radius: 1px;
# }
#
# .sidebar-toggle .icon-bar:nth-child(3) {
#     top: 100%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(2) {
#     opacity: 0;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(1) {
#     -ms-transform: rotate(45deg);
#     transform: rotate(45deg);
#     top: 50%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(3) {
#     top: 50%;
#     -ms-transform: rotate(-45deg);
#     transform: rotate(-45deg);
# }
#
# [class*="col-"].sidebar {
#     margin-bottom: auto !important;
#     padding-bottom: 0 !important;
# }
#
# .selector-buttons:hover {
#     background-color: #83ad04;
# }
# }
#
# .ui-accordion h3 {
#    margin-top: 0;
#     margin-bottom: 0px;
#     padding-top: 1px;
#     padding-bottom: 1px;
#     padding-left: 3px;
# }
# .ui-accordion h3:hover {
#     background-color: #FF6D00;
#     color: #FFFFFF;
#     cursor: pointer;
# }
# li.accordion-list-item {
#     list-style: none;
#     border-bottom: 1px solid #84919f;
#     margin-left: 0px;
#     padding-left: 5px;
# }
# a li.accordion-list-item {
#     font-size: 16px;
# }
#
# li.accordion-list-item:hover {
#     background-color: #FF6D00;
#     color: #FFF;
#     cursor: pointer;
# }
#
# a li.accordion-list-item:hover {
#     color: #0a2341;
#     cursor: pointer;
# }
#
# li.accordion-list-item.active-tenant {
#     background-color: #9c0;
#     padding-left: 5px;
#     margin-left: 0px;
# }
#
# a li.accordion-list-item.active-tenant {
#     color: #FFF;
# }
#
# /* AD AREAS */
# .banner-ad-wrapper {
#     padding: 50px 0;
#     text-align: center;
# }
#
# h3.sidebar-header {
#     text-transform: initial;
#     font-size: 24px;
#     border-bottom: 1px solid #84919f;
#     margin-bottom: 1px;
# }
# ul.tenant-list-ucr {
#     list-style: none;
#     padding: 0px;
#     margin: 0px;
# }
# li.tlucr-item {
#     border-bottom: 1px solid #84919f;
#     margin-left: 5px;
#     font-size: 16px;
# }
# .squeeze {
#     line-height: 1.5em !important;
# }
# /* SINGLE TENANT PAGE */
#
# .sidebar {
#     background-color: rgba(234, 233, 233, 0.55);
# }
#
# .tenant h1.post-title {
#     font-size: 35px;
#     font-weight: bold;
#     margin-top: 0px;
# }
#
# .header-updated-hr {
#     border-color: #9c0;
#     margin: -10px 0 3px;
# }
# .tenant-logo-home {
#     right: 15px;
#     top: 4px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# .tenant-logo {
#     right: 15px;
#     top: 8px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# @media (max-width: 991px){
#     .tenant-logo {
#         margin-right: 55px;
#     }
# }
# @media (max-width: 1414px){
#  .tenant h1.post-title {
#     font-size: 26px;
#     font-weight: bold;
#     margin-top: 40px;
# }
# }
# .tenant-logo  img {
#     max-width: 100%;
#     position: absolute;
#     bottom: 0;
#     right: 0;
# }
# .detail-box .detail-head {
#     background-color: #0a2341;
#     color: #fff;
#     text-transform: normal;
#     font-size: 18px;
#     padding: 2px 10px;
#     text-align: right;
#     font-weight: 400;
# }
# .detail-large-data {
#     text-align: right;
#     font-size: 78px;
#     line-height: 85px;
#     font-weight: bold;
#     color: #FF6D00;
# }
# .detail-sm-desc {
#     font-size: 13px;
#     text-align: right;
#     clear: both;
# }
# .detail-box {
#     margin-bottom: 25px;
# }
# .detail-data-table tr td {
#     padding-top: 5px !important;
#     padding-bottom: 5px !important;
# }
# .tenant-url-link {
#     margin-bottom: 15px;
# }
# .tenant-url-link a {
#     color: #FF6D00;
#     font-size: 16px;
#     font-weight: bold;
# }
# .tenant-url-link a:hover {
#     text-decoration: underline;
# }
# .tenant-stock-chart {
#     margin: 15px 0 30px;
#     margin-top: -20px;
# }
# .dschart {
#       margin-top: -20px;
# }
# td.data-label {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#     font-weight: 400;
#     line-height: 18px !important;
# }
# td.data-data {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#    font-weight: 400;
#     line-height: 18px !important;
# }
#
# .credit-rating td.data-label, .credit-rating td.data-data {
#     line-height: 22px !important;
#     width: 50%;
#     text-align: right;
#     font-size: 36px;
#     font-weight: bold;
#     color: #FF6D00;
#     padding: 10px 0 !important;
#  }
# .pros > h3, .cons > h3 {
#    padding-left: 11px;
# }
# .pro-item, .con-item, .eh-item {
#      font-size: 16px;
#      line-height: 20px;
#      margin-bottom: .8em;
# }
# .trend-info {
#     width: 33%;
#     float: left;
#     text-align: center;
#     margin-top: 8px;
# }
# .trend-year {
#     font-size: 18px;
#     color: #0a2341;
#     margin-top: -15px;
# }
# .trend-rate {
#     font-size: 28px;
#     font-weight: bold;
#     color: #0a2341;
# }
# .trend-image {
# width: 34%;
#     float: left;
#     text-align: center;
# }
# .tenant-description p {
#     font-size: 16px;
# }
# .tenant-description a {
# color: #FF6D00;
# }
# li.accordion-list-item.active {
#     background-color: #ff6d00;
# }
# li.accordion-list-item.active a {
#     color: #FFF;
# }
#
# /* MODAL */
# .modal-title {
#      font-size: 24px;
#      line-height: 24px;
# }
# .modal-body {
#     font-size: 14px;
#     line-height: 18px;
# }
# .modal-body a {
#     color: #99cc00;
# }
# .modal-header {
#     border-bottom: 1px solid #99cc00;
# }
# /* NET LEASE 101 */
# .caption-text {
# 	font-size: 16px;
# 	line-height: 1.4em;
# }
# .caption-head {
# 	font-family: Roboto Condensed, sans-serif;
# 	font-size: 21px;
# 	font-weight: bold;
# 	color: #0a2341;
# }
#
# /*OTHER*/
# i {
#   color: #9c0 !important;
# }
# .post-date {
#     font-size: 12px !important;
#     position: relative;
#     top: -2px !important;
#     font-style: italic;
#     color: #8e8e8e;
#     text-align: right;
# }
#
# #footer {
#   font-size: 14px;
# }
# .row:not(.sidebar-row){
#     overflow: hidden;
# }
#
# [class*="col-"].sidebar{
#     margin-bottom: -99999px;
#     padding-bottom: 99999px;
# }
#
# .subfooter {
#   text-align: center;
#   font-weight: 300;
# }
# .subfooter a {
#   font-weight: 400;
# }
#   </style>
#   <noscript>
#    <style type="text/css">
#     .wpb_animate_when_almost_visible { opacity: 1; }
#    </style>
#   </noscript>
#  </head>
#  <body class="tenant-template-default single single-tenant postid-1259 wpb-js-composer js-comp-ver-5.0 vc_responsive">
#   <div class="pace-overlay">
#   </div>
#   <div class="menu navbar navbar-static-top header-logo-left-menu-below oxy-mega-menu navbar-sticky navbar-not-mobile-stuck text-none" id="masthead" role="banner">
#    <div class="logo-navbar container-logo">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle collapsed" data-target=".main-navbar" data-toggle="collapse" type="button">
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a class="navbar-brand" href="https://www.netleaseadvisor.com">
#        <img alt="Net Lease Advisor" src="https://netleaseadvisor.com/wp-content/uploads/2017/02/Net-Lease-Advisor-Logo-03.png"/>
#       </a>
#       <div class="logo-sidebar">
#        <div class="sidebar-widget widget_text" id="text-7">
#         <div class="textwidget">
#          <div class="powered-by">
#           Powered by
#          </div>
#          <div>
#           <a href="http://www.calkain.com" target="_new">
#            <img src="https://netleaseadvisor.com/wp-content/uploads/2017/02/Calkain-logo-white-200w.png" width="110px"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="nav-container clearfix">
#      <nav class="collapse navbar-collapse main-navbar navbar-left" role="navigation">
#       <div class="menu-container">
#        <ul class="nav navbar-nav" id="menu-main">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-66" id="menu-item-66">
#          <a href="https://www.netleaseadvisor.com/">
#           HOME
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-728" id="menu-item-728">
#          <a href="https://www.netleaseadvisor.com/net-lease-101/">
#           NET LEASE 101
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-523" id="menu-item-523">
#          <a data-target="#521" data-toggle="modal" href="#">
#           CREDIT RATINGS
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-518" id="menu-item-518">
#          <a href="https://www.netleaseadvisor.com/contact/">
#           CONTACT
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="menu-sidebar">
#       </div>
#      </nav>
#     </div>
#    </div>
#   </div>
#   <div id="content" role="main">
#    <section class="section tenant">
#     <div class="container">
#      <div class="row">
#       <div class="col-md-9">
#        <p style="height: 45px;">
#        </p>
#        <article class="post-1259 tenant type-tenant status-publish has-post-thumbnail hentry sector-qsr" id="post-1259">
#         <h1 class="post-title">
#          Popeye’s TENANT OVERVIEW
#         </h1>
#         <div class="tenant-logo">
#          <img src="https://www.netleaseadvisor.com/wp-content/uploads/2018/09/PopeyesLouisianaKitchen-75-2.png"/>
#         </div>
#         <hr class="header-updated-hr"/>
#         <div class="post-date">
#          Updated: September 18, 2018
#         </div>
#         <div class="row">
#          <div class="col-md-8">
#           <div class="figure fade-in text-center figcaption-middle">
#            <img alt="" class="attachment-large size-large wp-post-image" height="364" sizes="(max-width: 800px) 100vw, 800px" src="https://www.netleaseadvisor.com/wp-content/uploads/2018/09/NLA-Popeyes-1100x500-800x364.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2018/09/NLA-Popeyes-1100x500-800x364.jpg 800w, https://www.netleaseadvisor.com/wp-content/uploads/2018/09/NLA-Popeyes-1100x500-300x136.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2018/09/NLA-Popeyes-1100x500-768x349.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2018/09/NLA-Popeyes-1100x500.jpg 1100w" width="800"/>
#           </div>
#           <div class="pros_cons row">
#            <div class="pros col-md-6">
#             <h3>
#              Pros
#             </h3>
#             <ul class="pros-list">
#              <li class="pro-item">
#               No landlord responsibilities
#              </li>
#              <li class="pro-item">
#               Rental increases in the primary term
#              </li>
#             </ul>
#            </div>
#            <div class="cons col-md-6">
#             <h3>
#              Cons
#             </h3>
#             <ul class="cons-list">
#              <li class="con-item">
#               Non-investment grade credit
#              </li>
#              <li class="con-item">
#               Franchisee operators
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="tenant-description">
#            <h2>
#             Tenant Description
#            </h2>
#            <p>
#             Popeye’s Louisiana Kitchen, or Popeye’s as it is commonly known, is a chain of fried chicken fast food restaurants.
#             <br/>
#             <br/>
#             Popeye’s is an attractive net lease investment due to their triple net leases with rental increases and their strong locations. Popeye’s, like most QSRs, sign triple net lease that relieve the investor of any landlord responsibilities. The leases will typically feature rental increases in the base term, every five years or annually, depending on the lease. Popeye’s occupies buildings with strong real estate fundamentals, such as good visibility from a highly trafficked road. Their layout is common among QSR tenants, which makes backfilling the property much easier. Nearly all of the Popeye locations are franchises, making it critical investors evaluate the financial strength of the restaurant operator.
#             <br/>
#             <br/>
#             Popeye’s was found in 1972 in New Orleans. In 2017, Restaurant Brands International (RBI), acquired the entire Popeye’s chain. Today, the 2,975 Popeye’s restaurants are part of the larger RBI system that totals 24,791 restaurants across 100 countries and US territories.
#             <br/>
#            </p>
#           </div>
#           <div class="tenant-url-link">
#            <a href="http://popeyes.com" target="_blank">
#             popeyes.com
#            </a>
#           </div>
#           <!-- TradingView Widget BEGIN -->
#           <script src="https://s3.tradingview.com/tv.js" type="text/javascript">
#           </script>
#           <script type="text/javascript">
#            new TradingView.widget({
#   "width": 665,
#   "height": 400,
#   "symbol": "QSR",
#   "interval": "W",
#   "timezone": "America/New_York",
#   "theme": "Light",
#   "style": "2",
#   "locale": "en",
#   "toolbar_bg": "rgba(255, 109, 0, 1)",
#   "enable_publishing": false,
#   "withdateranges": true,
#   "allow_symbol_change": true,
#   "details": true,
#   "hideideas": true
# });
#           </script>
#           <!-- TradingView Widget END -->
#          </div>
#          <div class="col-md-4">
#           <div class="detail-box">
#            <div class="detail-head">
#             Average Cap Rate
#            </div>
#            <div class="detail-large-data">
#             5.44%
#            </div>
#            <div class="detail-sm-desc">
#             12 mo avg with 10+ yr lease term
#            </div>
#           </div>
#           <div class="detail-box average-property-lease">
#            <div class="detail-head">
#             Average Property &amp; Lease
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                Average Sale Price
#               </td>
#               <td class="data-data">
#                $2,089,169
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                NOI
#               </td>
#               <td class="data-data">
#                $113,651
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                $/Square Foot
#               </td>
#               <td class="data-data">
#                $700 - $1,000
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Building SF
#               </td>
#               <td class="data-data">
#                2,000 - 3,000
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lot Size
#               </td>
#               <td class="data-data">
#                0.5 - 1.0 Acres
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lease Term
#               </td>
#               <td class="data-data">
#                15 - 20 Years
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Escalations
#               </td>
#               <td class="data-data">
#                Varies
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Stock Symbol
#               </td>
#               <td class="data-data">
#                QSR
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="detail-box credit-rating">
#            <div class="detail-head">
#             Credit Rating
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                S&amp;P
#               </td>
#               <td class="data-data">
#                B+
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Moody's
#               </td>
#               <td class="data-data">
#                N/A
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc" style="font-style: italic;">
#            </div>
#           </div>
#           <div class="detail-box average-cap-rate-trend">
#            <div class="detail-head">
#             Average Cap Rate Trend
#            </div>
#            <div class="cap-rate-trend-continer">
#             <div class="trend-info">
#              <div class="trend-left">
#               <div class="trend-rate">
#                5.33%
#               </div>
#               <div class="trend-year">
#                2017
#               </div>
#              </div>
#             </div>
#             <div class="trend-image">
#              <img src="/wp-content/plugins/post-accordion-widget-plugin/images/up.png"/>
#             </div>
#             <div class="trend-info">
#              <div class="trend-right">
#               <div class="trend-rate">
#                5.51%
#               </div>
#               <div class="trend-year">
#                2018
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="detail-sm-desc" style="padding-top: 5px;">
#             Rates reflect last 12 mos, short and long-term
#            </div>
#           </div>
#           <div class="detail-box recent-sales-comps">
#            <div class="detail-head">
#             Recent Sales Comps
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Marysville, WA
#               </td>
#               <td class="data-data">
#                5.04%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Cincinnati, OH
#               </td>
#               <td class="data-data">
#                5.75%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Greenville, NC
#               </td>
#               <td class="data-data">
#                5.67%
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc">
#            </div>
#           </div>
#           <div class="detail-box featured-net-lease-listing">
#            <div class="detail-head">
#             Featured Tenant Profiles
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/Advance-Auto-Parts-St-Louis-MO-calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#                Advance Auto Parts
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Automotive
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                6.01%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/pollo-tropical/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2018/08/Pollo-Tropical-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/pollo-tropical/">
#                Pollo Tropical
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                QSR
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                4.87%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/Oreilly-oakland-park-fl-calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#                O’Reilly Auto Parts
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Automotive
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                5.66%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </article>
#       </div>
#       <div class="col-md-3 sidebar">
#        <div class="sidebar-widget tax_accordion_widget_class" id="tax_accordion_widget-2">
#         <div class="sidebar-collapse-control-btn">
#          <button class="sidebar-toggle offscreen" type="button">
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="container-fluid">
#          <div class="row">
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-sector">
#             SECTOR
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-alpha">
#             A-Z
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="accordion-sector" id="accordion-sector" style="display:none;">
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Automotive
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#             Advance Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/autozone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/autozone/">
#             AutoZone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bridgestone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bridgestone/">
#             Bridgestone/Firestone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
#             Christian Brothers Automotive
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/jiffy-lube/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jiffy-lube/">
#             Jiffy Lube
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">
#             Napa Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#             O’Reilly Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/pep-boys-auto/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pep-boys-auto/">
#             Pep Boys Auto
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Bank
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/bank-of-america/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bank-of-america/">
#             Bank of America
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bankunited/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bankunited/">
#             BankUnited
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bbt-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bbt-bank/">
#             BB&amp;T Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">
#             BMO Harris Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/chase-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chase-bank/">
#             Chase Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/pnc-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pnc-bank/">
#             PNC Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/suntrust/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">
#             SunTrust
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/td-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">
#             TD Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Big Box
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/best-buy/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/best-buy/">
#             Best Buy
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/hobby-lobby/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hobby-lobby/">
#             Hobby Lobby
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/kohls/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/kohls/">
#             Kohl’s
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#             Tractor Supply Co.
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/walmart/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">
#             Walmart
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Casual Dining
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/applebees/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/applebees/">
#             Applebee’s
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bob-evans/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bob-evans/">
#             Bob Evans
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/cheddars-scratch-kitchen/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cheddars-scratch-kitchen/">
#             Cheddar’s Scratch Kitchen
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">
#             Chili’s Grill &amp; Bar
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/cracker-barrel/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cracker-barrel/">
#             Cracker Barrel
# ...
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/sherwin-williams/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sherwin-williams/">
#             Sherwin-Williams
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/sonic/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sonic/">
#             Sonic
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/starbucks-coffee/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/starbucks-coffee/">
#             Starbucks
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/steak-n-shake/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/steak-n-shake/">
#             Steak ‘n Shake
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/suntrust/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">
#             SunTrust
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           T
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/taco-bell/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/taco-bell/">
#             Taco Bell
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/td-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">
#             TD Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/the-learning-experience/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/the-learning-experience/">
#             The Learning Experience
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#             Tractor Supply Co.
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           V
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/verizon/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/verizon/">
#             Verizon Wireless
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           W
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/walgreens/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walgreens/">
#             Walgreens
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/walmart/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">
#             Walmart
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wawa/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wawa/">
#             Wawa
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wegmans/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wegmans/">
#             Wegmans
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wendys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wendys/">
#             Wendy’s
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Z
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/zaxbys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/zaxbys/">
#             Zaxby’s
#            </li>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-10">
#         <div class="textwidget">
#          <a href="/bov-request">
#           <img src="https://netleaseadvisor.com/wp-content/uploads/2017/06/ad-calkain-bov.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-8">
#         <h3 class="sidebar-header">
#          Understanding Credit Ratings
#         </h3>
#         <div class="textwidget">
#          <ul class="tenant-list-ucr">
#           <li class="tlucr-item">
#            <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#             View Credit Rating Chart
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="http://www.spratings.com/en_US/understanding-ratings" target="_new">
#             Standard &amp; Poors
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="https://www.moodys.com/Pages/amr002002.aspx" target="_new">
#             Moody's
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-9">
#         <h3 class="sidebar-header">
#          Have a Research Project?
#         </h3>
#         <div class="textwidget">
#          <div class="squeeze">
#           Our experienced team provides unique insight to the net lease industry.  We can provide an in-depth analysis to a specific segment or assess an investment on your behalf.  Let us know your needs.
#          </div>
#          <a href="/contact">
#           <div class="sidebar-contact-btn btn btn-block btn-success">
#            Contact Us
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <footer id="footer" role="contentinfo">
#     <section class="section">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-6">
#          <div class="textwidget">
#           All logos are ©Copyright, ®Registered Trademarks and courtesy of their respective companies, and are displayed in this website for the sole purpose of brand recognition in tenant labeling.
#           <br/>
#           ©2017-2018 netleaseadvisor.com,
#           <a href="http://calkain.com" target="_new">
#            Calkain Companies LLC
#           </a>
#           . All Rights Reserved.
#           <br/>
#           12930 Worldgate Drive, Suite 150 | Herndon, VA 20170 |
#  Tel: (703) 787-4714
#           <br/>
#           <span style="color:#a0a0a0; font-weight:bold;">
#            Developed by
#           </span>
#           <a href="mailto:mjvdesign@gmail.com?subject=Ref: netleaseadvisor.com">
#            <img alt="MJVdesign" border="0" src="/wp-content/uploads/2017/03/mjvdesign_logo_transp_light.png" style="margin-top: 2px; margin-left: -4px;" title="Email MJVdesign"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="section subfooter">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-11">
#          <div class="textwidget">
#           <a href="https://www.netleaseadvisor.com">
#            Home
#           </a>
#           |
#           <a href="/net-lease-101">
#            Net Lease 101
#           </a>
#           |
#           <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#            Credit Rating Chart
#           </a>
#           |
#           <a href="/contact">
#            Contact
#           </a>
#           |
#           <a href="/bov-request">
#            BOV Request
#           </a>
#           |
#           <a href="https://calkain.com">
#            Calkain.com
#           </a>
#           |
#           <a href="https://calkain.com/research">
#            Calkain Research
#           </a>
#           |
#           <a href="https://calkain.com/properties">
#            Calkain Properties
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </footer>
#   </div>
#   <!-- Fixing the Back to top button -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   ga('create', 'UA-4933828-6', 'auto');
#
#   ga('send', 'pageview');
#   </script>
#   <div class="modal fade" id="40" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        Subscribe
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        [mc4wp_form]
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="521" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-lg" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CREDIT RATING CHART
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        <img alt="Net Lease Advisor Credit Rating Chart" class="alignnone wp-image-1087 size-full" height="883" sizes="(max-width: 900px) 100vw, 900px" src="https://netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg 900w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-300x294.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-768x753.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-800x785.jpg 800w" width="900"/>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="516" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CONTACT
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        For specific inquiries regarding this website or tenant information, please contact:
#       </p>
#       <p>
#        <strong>
#         Vinky Marolia
#        </strong>
#        <br/>
#        Research Analyst, Calkain Companies
#        <br/>
#        (571) 449-8146
#        <br/>
#        <a href="mailto:research@calkain.com">
#         research@calkain.com
#        </a>
#       </p>
#       <p>
#        For general inquiries or phone numbers and addresses for all of our office locations:
#        <br/>
#        <a href="http://calkain.com/contact/" target="_blank">
#         Contact Calkain
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/accordion.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/post-accordion-widget-plugin/controller.js?ver=9.9" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var click_object = {"ajax_url":"https:\/\/www.netleaseadvisor.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/adrotate-pro/library/jquery.adrotate.clicktracker.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.netleaseadvisor.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.0.3" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/slider.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/button.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-sliderAccess.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.cookie.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.navgoco.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var oxyThemeData = {"navbarScrolledPoint":"30","navbarHeight":"100","navbarScrolled":"50","siteLoader":"off","menuClose":"off","scrollFinishedMessage":"No more items to load.","hoverMenu":{"hoverActive":true,"hoverDelay":200,"hoverFadeDelay":200}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/js/theme.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts//js/functions.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/wp-embed.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
links=soup.findAll('a')

# %%
t=1

# %%
for i in links:
    print(t,i)
    t+=1
# Out:
# 1 <a class="navbar-brand" href="https://www.netleaseadvisor.com">
# <img alt="Net Lease Advisor" src="https://netleaseadvisor.com/wp-content/uploads/2017/02/Net-Lease-Advisor-Logo-03.png"/>
# </a>
# 2 <a href="http://www.calkain.com" target="_new"><img src="https://netleaseadvisor.com/wp-content/uploads/2017/02/Calkain-logo-white-200w.png" width="110px"/></a>
# 3 <a href="https://www.netleaseadvisor.com/">HOME</a>
# 4 <a href="https://www.netleaseadvisor.com/net-lease-101/">NET LEASE 101</a>
# 5 <a data-target="#521" data-toggle="modal" href="#">CREDIT RATINGS</a>
# 6 <a href="https://www.netleaseadvisor.com/contact/">CONTACT</a>
# 7 <a href="http://popeyes.com" target="_blank">popeyes.com</a>
# 8 <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/"><img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/Advance-Auto-Parts-St-Louis-MO-calkain-150x150.jpg"/></a>
# 9 <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">Advance Auto Parts</a>
# 10 <a href="https://www.netleaseadvisor.com/tenant/pollo-tropical/"><img src="https://www.netleaseadvisor.com/wp-content/uploads/2018/08/Pollo-Tropical-150x150.jpg"/></a>
# 11 <a href="https://www.netleaseadvisor.com/tenant/pollo-tropical/">Pollo Tropical</a>
# 12 <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/"><img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/Oreilly-oakland-park-fl-calkain-150x150.jpg"/></a>
# 13 <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">O’Reilly Auto Parts</a>
# 14 <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">Advance Auto Parts</li></a>
# 15 <a href="https://www.netleaseadvisor.com/tenant/autozone/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/autozone/">AutoZone</li></a>
# 16 <a href="https://www.netleaseadvisor.com/tenant/bridgestone/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bridgestone/">Bridgestone/Firestone</li></a>
# 17 <a href="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">Christian Brothers Automotive</li></a>
# 18 <a href="https://www.netleaseadvisor.com/tenant/jiffy-lube/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jiffy-lube/">Jiffy Lube</li></a>
# 19 <a href="https://www.netleaseadvisor.com/tenant/napa-auto-parts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">Napa Auto Parts</li></a>
# 20 <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">O’Reilly Auto Parts</li></a>
# 21 <a href="https://www.netleaseadvisor.com/tenant/pep-boys-auto/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pep-boys-auto/">Pep Boys Auto</li></a>
# 22 <a href="https://www.netleaseadvisor.com/tenant/bank-of-america/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bank-of-america/">Bank of America</li></a>
# 23 <a href="https://www.netleaseadvisor.com/tenant/bankunited/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bankunited/">BankUnited</li></a>
# 24 <a href="https://www.netleaseadvisor.com/tenant/bbt-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bbt-bank/">BB&amp;T Bank</li></a>
# 25 <a href="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">BMO Harris Bank</li></a>
# 26 <a href="https://www.netleaseadvisor.com/tenant/chase-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chase-bank/">Chase Bank</li></a>
# 27 <a href="https://www.netleaseadvisor.com/tenant/pnc-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pnc-bank/">PNC Bank</li></a>
# 28 <a href="https://www.netleaseadvisor.com/tenant/suntrust/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">SunTrust</li></a>
# 29 <a href="https://www.netleaseadvisor.com/tenant/td-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">TD Bank</li></a>
# 30 <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">Wells Fargo</li></a>
# 31 <a href="https://www.netleaseadvisor.com/tenant/best-buy/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/best-buy/">Best Buy</li></a>
# 32 <a href="https://www.netleaseadvisor.com/tenant/hobby-lobby/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hobby-lobby/">Hobby Lobby</li></a>
# 33 <a href="https://www.netleaseadvisor.com/tenant/kohls/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/kohls/">Kohl’s</li></a>
# 34 <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">Tractor Supply Co.</li></a>
# 35 <a href="https://www.netleaseadvisor.com/tenant/walmart/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">Walmart</li></a>
# 36 <a href="https://www.netleaseadvisor.com/tenant/applebees/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/applebees/">Applebee’s</li></a>
# 37 <a href="https://www.netleaseadvisor.com/tenant/bob-evans/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bob-evans/">Bob Evans</li></a>
# 38 <a href="https://www.netleaseadvisor.com/tenant/cheddars-scratch-kitchen/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cheddars-scratch-kitchen/">Cheddar’s Scratch Kitchen</li></a>
# 39 <a href="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">Chili’s Grill &amp; Bar</li></a>
# 40 <a href="https://www.netleaseadvisor.com/tenant/cracker-barrel/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cracker-barrel/">Cracker Barrel</li></a>
# 41 <a href="https://www.netleaseadvisor.com/tenant/dennys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dennys/">Denny’s</li></a>
# 42 <a href="https://www.netleaseadvisor.com/tenant/ihop/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ihop/">IHOP</li></a>
# 43 <a href="https://www.netleaseadvisor.com/tenant/red-lobster/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/red-lobster/">Red Lobster</li></a>
# 44 <a href="https://www.netleaseadvisor.com/tenant/7-eleven/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/7-eleven/">7-Eleven</li></a>
# 45 <a href="https://www.netleaseadvisor.com/tenant/circle-k/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/circle-k/">Circle K</li></a>
# 46 <a href="https://www.netleaseadvisor.com/tenant/sheetz/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sheetz/">Sheetz</li></a>
# 47 <a href="https://www.netleaseadvisor.com/tenant/shell-oil/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/shell-oil/">Shell Oil</li></a>
# 48 <a href="https://www.netleaseadvisor.com/tenant/wawa/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wawa/">Wawa</li></a>
# 49 <a href="https://www.netleaseadvisor.com/tenant/dollar-general/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dollar-general/">Dollar General</li></a>
# 50 <a href="https://www.netleaseadvisor.com/tenant/dollar-tree/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dollar-tree/">Dollar Tree</li></a>
# 51 <a href="https://www.netleaseadvisor.com/tenant/family-dollar/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/family-dollar/">Family Dollar</li></a>
# 52 <a href="https://www.netleaseadvisor.com/tenant/freds-super-dollar/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/freds-super-dollar/">Fred’s Super Dollar</li></a>
# 53 <a href="https://www.netleaseadvisor.com/tenant/the-learning-experience/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/the-learning-experience/">The Learning Experience</li></a>
# 54 <a href="https://www.netleaseadvisor.com/tenant/aldi/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/aldi/">ALDI</li></a>
# 55 <a href="https://www.netleaseadvisor.com/tenant/wegmans/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wegmans/">Wegmans</li></a>
# 56 <a href="https://www.netleaseadvisor.com/tenant/affordable-dentures/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/affordable-dentures/">Affordable Dentures</li></a>
# 57 <a href="https://www.netleaseadvisor.com/tenant/davita/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/davita/">DaVita</li></a>
# 58 <a href="https://www.netleaseadvisor.com/tenant/fresenius-medical-care/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/fresenius-medical-care/">Fresenius Medical Care</li></a>
# 59 <a href="https://www.netleaseadvisor.com/tenant/cvs-pharmacy/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cvs-pharmacy/">CVS Pharmacy</li></a>
# 60 <a href="https://www.netleaseadvisor.com/tenant/rite-aid/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/rite-aid/">Rite Aid</li></a>
# 61 <a href="https://www.netleaseadvisor.com/tenant/walgreens/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walgreens/">Walgreens</li></a>
# 62 <a href="https://www.netleaseadvisor.com/tenant/arbys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/arbys/">Arby’s</li></a>
# 63 <a href="https://www.netleaseadvisor.com/tenant/bojangles/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bojangles/">Bojangles’</li></a>
# 64 <a href="https://www.netleaseadvisor.com/tenant/burger-king/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/burger-king/">Burger King</li></a>
# 65 <a href="https://www.netleaseadvisor.com/tenant/captain-ds/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/captain-ds/">Captain D’s</li></a>
# 66 <a href="https://www.netleaseadvisor.com/tenant/chick-fil-a/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chick-fil-a/">Chick-fil-A</li></a>
# 67 <a href="https://www.netleaseadvisor.com/tenant/chipotle/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chipotle/">Chipotle</li></a>
# 68 <a href="https://www.netleaseadvisor.com/tenant/churchs-chicken/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/churchs-chicken/">Church’s Chicken</li></a>
# 69 <a href="https://www.netleaseadvisor.com/tenant/dairy-queen/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dairy-queen/">Dairy Queen</li></a>
# 70 <a href="https://www.netleaseadvisor.com/tenant/dunkin-donuts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dunkin-donuts/">Dunkin’ Donuts</li></a>
# 71 <a href="https://www.netleaseadvisor.com/tenant/hardees/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hardees/">Hardee’s</li></a>
# 72 <a href="https://www.netleaseadvisor.com/tenant/jack-in-the-box/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jack-in-the-box/">Jack in the Box</li></a>
# 73 <a href="https://www.netleaseadvisor.com/tenant/kfc/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/kfc/">KFC</li></a>
# 74 <a href="https://www.netleaseadvisor.com/tenant/mcdonalds/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/mcdonalds/">McDonald’s</li></a>
# 75 <a href="https://www.netleaseadvisor.com/tenant/panera-bread/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/panera-bread/">Panera Bread</li></a>
# 76 <a href="https://www.netleaseadvisor.com/tenant/pdq/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pdq/">PDQ</li></a>
# 77 <a href="https://www.netleaseadvisor.com/tenant/pizza-hut/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pizza-hut/">Pizza Hut</li></a>
# 78 <a href="https://www.netleaseadvisor.com/tenant/pollo-tropical/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pollo-tropical/">Pollo Tropical</li></a>
# 79 <a href="https://www.netleaseadvisor.com/tenant/popeyes/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/popeyes/">Popeye’s</li></a>
# 80 <a href="https://www.netleaseadvisor.com/tenant/raising-canes/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/raising-canes/">Raising Cane’s</li></a>
# 81 <a href="https://www.netleaseadvisor.com/tenant/sonic/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sonic/">Sonic</li></a>
# 82 <a href="https://www.netleaseadvisor.com/tenant/starbucks-coffee/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/starbucks-coffee/">Starbucks</li></a>
# 83 <a href="https://www.netleaseadvisor.com/tenant/steak-n-shake/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/steak-n-shake/">Steak ‘n Shake</li></a>
# 84 <a href="https://www.netleaseadvisor.com/tenant/taco-bell/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/taco-bell/">Taco Bell</li></a>
# 85 <a href="https://www.netleaseadvisor.com/tenant/wendys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wendys/">Wendy’s</li></a>
# 86 <a href="https://www.netleaseadvisor.com/tenant/zaxbys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/zaxbys/">Zaxby’s</li></a>
# 87 <a href="https://www.netleaseadvisor.com/tenant/ashley-furniture/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ashley-furniture/">Ashley Furniture HomeStore</li></a>
# 88 <a href="https://www.netleaseadvisor.com/tenant/fedex/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/fedex/">FedEx</li></a>
# 89 <a href="https://www.netleaseadvisor.com/tenant/la-fitness/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/la-fitness/">LA Fitness</li></a>
# 90 <a href="https://www.netleaseadvisor.com/tenant/mattress-firm/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/mattress-firm/">Mattress Firm</li></a>
# 91 <a href="https://www.netleaseadvisor.com/tenant/sherwin-williams/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sherwin-williams/">Sherwin-Williams</li></a>
# 92 <a href="https://www.netleaseadvisor.com/tenant/verizon/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/verizon/">Verizon Wireless</li></a>
# 93 <a href="https://www.netleaseadvisor.com/tenant/7-eleven/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/7-eleven/">7-Eleven</li></a>
# 94 <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">Advance Auto Parts</li></a>
# 95 <a href="https://www.netleaseadvisor.com/tenant/affordable-dentures/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/affordable-dentures/">Affordable Dentures</li></a>
# 96 <a href="https://www.netleaseadvisor.com/tenant/aldi/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/aldi/">ALDI</li></a>
# 97 <a href="https://www.netleaseadvisor.com/tenant/applebees/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/applebees/">Applebee’s</li></a>
# 98 <a href="https://www.netleaseadvisor.com/tenant/arbys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/arbys/">Arby’s</li></a>
# 99 <a href="https://www.netleaseadvisor.com/tenant/ashley-furniture/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ashley-furniture/">Ashley Furniture HomeStore</li></a>
# 100 <a href="https://www.netleaseadvisor.com/tenant/autozone/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/autozone/">AutoZone</li></a>
# 101 <a href="https://www.netleaseadvisor.com/tenant/bank-of-america/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bank-of-america/">Bank of America</li></a>
# 102 <a href="https://www.netleaseadvisor.com/tenant/bankunited/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bankunited/">BankUnited</li></a>
# 103 <a href="https://www.netleaseadvisor.com/tenant/bbt-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bbt-bank/">BB&amp;T Bank</li></a>
# 104 <a href="https://www.netleaseadvisor.com/tenant/best-buy/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/best-buy/">Best Buy</li></a>
# 105 <a href="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">BMO Harris Bank</li></a>
# 106 <a href="https://www.netleaseadvisor.com/tenant/bob-evans/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bob-evans/">Bob Evans</li></a>
# 107 <a href="https://www.netleaseadvisor.com/tenant/bojangles/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bojangles/">Bojangles’</li></a>
# 108 <a href="https://www.netleaseadvisor.com/tenant/bridgestone/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bridgestone/">Bridgestone/Firestone</li></a>
# 109 <a href="https://www.netleaseadvisor.com/tenant/burger-king/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/burger-king/">Burger King</li></a>
# 110 <a href="https://www.netleaseadvisor.com/tenant/captain-ds/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/captain-ds/">Captain D’s</li></a>
# 111 <a href="https://www.netleaseadvisor.com/tenant/chase-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chase-bank/">Chase Bank</li></a>
# 112 <a href="https://www.netleaseadvisor.com/tenant/cheddars-scratch-kitchen/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cheddars-scratch-kitchen/">Cheddar’s Scratch Kitchen</li></a>
# 113 <a href="https://www.netleaseadvisor.com/tenant/chick-fil-a/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chick-fil-a/">Chick-fil-A</li></a>
# 114 <a href="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">Chili’s Grill &amp; Bar</li></a>
# 115 <a href="https://www.netleaseadvisor.com/tenant/chipotle/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chipotle/">Chipotle</li></a>
# 116 <a href="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">Christian Brothers Automotive</li></a>
# 117 <a href="https://www.netleaseadvisor.com/tenant/churchs-chicken/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/churchs-chicken/">Church’s Chicken</li></a>
# 118 <a href="https://www.netleaseadvisor.com/tenant/circle-k/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/circle-k/">Circle K</li></a>
# 119 <a href="https://www.netleaseadvisor.com/tenant/cracker-barrel/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cracker-barrel/">Cracker Barrel</li></a>
# 120 <a href="https://www.netleaseadvisor.com/tenant/cvs-pharmacy/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cvs-pharmacy/">CVS Pharmacy</li></a>
# 121 <a href="https://www.netleaseadvisor.com/tenant/dairy-queen/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dairy-queen/">Dairy Queen</li></a>
# 122 <a href="https://www.netleaseadvisor.com/tenant/davita/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/davita/">DaVita</li></a>
# 123 <a href="https://www.netleaseadvisor.com/tenant/dennys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dennys/">Denny’s</li></a>
# 124 <a href="https://www.netleaseadvisor.com/tenant/dollar-general/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dollar-general/">Dollar General</li></a>
# 125 <a href="https://www.netleaseadvisor.com/tenant/dollar-tree/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dollar-tree/">Dollar Tree</li></a>
# 126 <a href="https://www.netleaseadvisor.com/tenant/dunkin-donuts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dunkin-donuts/">Dunkin’ Donuts</li></a>
# 127 <a href="https://www.netleaseadvisor.com/tenant/family-dollar/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/family-dollar/">Family Dollar</li></a>
# 128 <a href="https://www.netleaseadvisor.com/tenant/fedex/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/fedex/">FedEx</li></a>
# 129 <a href="https://www.netleaseadvisor.com/tenant/freds-super-dollar/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/freds-super-dollar/">Fred’s Super Dollar</li></a>
# 130 <a href="https://www.netleaseadvisor.com/tenant/fresenius-medical-care/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/fresenius-medical-care/">Fresenius Medical Care</li></a>
# 131 <a href="https://www.netleaseadvisor.com/tenant/hardees/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hardees/">Hardee’s</li></a>
# 132 <a href="https://www.netleaseadvisor.com/tenant/hobby-lobby/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hobby-lobby/">Hobby Lobby</li></a>
# 133 <a href="https://www.netleaseadvisor.com/tenant/ihop/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ihop/">IHOP</li></a>
# 134 <a href="https://www.netleaseadvisor.com/tenant/jack-in-the-box/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jack-in-the-box/">Jack in the Box</li></a>
# 135 <a href="https://www.netleaseadvisor.com/tenant/jiffy-lube/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jiffy-lube/">Jiffy Lube</li></a>
# 136 <a href="https://www.netleaseadvisor.com/tenant/kfc/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/kfc/">KFC</li></a>
# 137 <a href="https://www.netleaseadvisor.com/tenant/kohls/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/kohls/">Kohl’s</li></a>
# 138 <a href="https://www.netleaseadvisor.com/tenant/la-fitness/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/la-fitness/">LA Fitness</li></a>
# 139 <a href="https://www.netleaseadvisor.com/tenant/mattress-firm/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/mattress-firm/">Mattress Firm</li></a>
# 140 <a href="https://www.netleaseadvisor.com/tenant/mcdonalds/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/mcdonalds/">McDonald’s</li></a>
# 141 <a href="https://www.netleaseadvisor.com/tenant/napa-auto-parts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">Napa Auto Parts</li></a>
# 142 <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">O’Reilly Auto Parts</li></a>
# 143 <a href="https://www.netleaseadvisor.com/tenant/panera-bread/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/panera-bread/">Panera Bread</li></a>
# 144 <a href="https://www.netleaseadvisor.com/tenant/pdq/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pdq/">PDQ</li></a>
# 145 <a href="https://www.netleaseadvisor.com/tenant/pep-boys-auto/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pep-boys-auto/">Pep Boys Auto</li></a>
# 146 <a href="https://www.netleaseadvisor.com/tenant/pizza-hut/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pizza-hut/">Pizza Hut</li></a>
# 147 <a href="https://www.netleaseadvisor.com/tenant/pnc-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pnc-bank/">PNC Bank</li></a>
# 148 <a href="https://www.netleaseadvisor.com/tenant/pollo-tropical/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pollo-tropical/">Pollo Tropical</li></a>
# 149 <a href="https://www.netleaseadvisor.com/tenant/popeyes/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/popeyes/">Popeye’s</li></a>
# 150 <a href="https://www.netleaseadvisor.com/tenant/raising-canes/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/raising-canes/">Raising Cane’s</li></a>
# 151 <a href="https://www.netleaseadvisor.com/tenant/red-lobster/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/red-lobster/">Red Lobster</li></a>
# 152 <a href="https://www.netleaseadvisor.com/tenant/rite-aid/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/rite-aid/">Rite Aid</li></a>
# 153 <a href="https://www.netleaseadvisor.com/tenant/sheetz/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sheetz/">Sheetz</li></a>
# 154 <a href="https://www.netleaseadvisor.com/tenant/shell-oil/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/shell-oil/">Shell Oil</li></a>
# 155 <a href="https://www.netleaseadvisor.com/tenant/sherwin-williams/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sherwin-williams/">Sherwin-Williams</li></a>
# 156 <a href="https://www.netleaseadvisor.com/tenant/sonic/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sonic/">Sonic</li></a>
# 157 <a href="https://www.netleaseadvisor.com/tenant/starbucks-coffee/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/starbucks-coffee/">Starbucks</li></a>
# 158 <a href="https://www.netleaseadvisor.com/tenant/steak-n-shake/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/steak-n-shake/">Steak ‘n Shake</li></a>
# 159 <a href="https://www.netleaseadvisor.com/tenant/suntrust/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">SunTrust</li></a>
# 160 <a href="https://www.netleaseadvisor.com/tenant/taco-bell/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/taco-bell/">Taco Bell</li></a>
# 161 <a href="https://www.netleaseadvisor.com/tenant/td-bank/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">TD Bank</li></a>
# 162 <a href="https://www.netleaseadvisor.com/tenant/the-learning-experience/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/the-learning-experience/">The Learning Experience</li></a>
# 163 <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">Tractor Supply Co.</li></a>
# 164 <a href="https://www.netleaseadvisor.com/tenant/verizon/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/verizon/">Verizon Wireless</li></a>
# 165 <a href="https://www.netleaseadvisor.com/tenant/walgreens/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walgreens/">Walgreens</li></a>
# 166 <a href="https://www.netleaseadvisor.com/tenant/walmart/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">Walmart</li></a>
# 167 <a href="https://www.netleaseadvisor.com/tenant/wawa/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wawa/">Wawa</li></a>
# 168 <a href="https://www.netleaseadvisor.com/tenant/wegmans/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wegmans/">Wegmans</li></a>
# 169 <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">Wells Fargo</li></a>
# 170 <a href="https://www.netleaseadvisor.com/tenant/wendys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wendys/">Wendy’s</li></a>
# 171 <a href="https://www.netleaseadvisor.com/tenant/zaxbys/"><li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/zaxbys/">Zaxby’s</li></a>
# 172 <a href="/bov-request"><img src="https://netleaseadvisor.com/wp-content/uploads/2017/06/ad-calkain-bov.jpg"/></a>
# 173 <a data-target="#521" data-toggle="modal" href="javascript:void(0);">View Credit Rating Chart</a>
# 174 <a href="http://www.spratings.com/en_US/understanding-ratings" target="_new">Standard &amp; Poors</a>
# 175 <a href="https://www.moodys.com/Pages/amr002002.aspx" target="_new">Moody's</a>
# 176 <a href="/contact"><div class="sidebar-contact-btn btn btn-block btn-success">Contact Us</div></a>
# 177 <a href="http://calkain.com" target="_new">Calkain Companies LLC</a>
# 178 <a href="mailto:mjvdesign@gmail.com?subject=Ref: netleaseadvisor.com">
# <img alt="MJVdesign" border="0" src="/wp-content/uploads/2017/03/mjvdesign_logo_transp_light.png" style="margin-top: 2px; margin-left: -4px;" title="Email MJVdesign"/></a>
# 179 <a href="https://www.netleaseadvisor.com">Home</a>
# 180 <a href="/net-lease-101">Net Lease 101</a>
# 181 <a data-target="#521" data-toggle="modal" href="javascript:void(0);">Credit Rating Chart</a>
# 182 <a href="/contact">Contact</a>
# 183 <a href="/bov-request"> BOV Request</a>
# 184 <a href="https://calkain.com">Calkain.com</a>
# 185 <a href="https://calkain.com/research">Calkain Research</a>
# 186 <a href="https://calkain.com/properties">Calkain Properties</a>
# 187 <a href="mailto:research@calkain.com">research@calkain.com</a>
# 188 <a href="http://calkain.com/contact/" target="_blank">Contact Calkain</a>

# %%
QSR_links=[]

# %%
for link in links[61:86]:
    QSR_links.append(link['href'])
    print(link['href'])
# Out:
# https://www.netleaseadvisor.com/tenant/arbys/
# https://www.netleaseadvisor.com/tenant/bojangles/
# https://www.netleaseadvisor.com/tenant/burger-king/
# https://www.netleaseadvisor.com/tenant/captain-ds/
# https://www.netleaseadvisor.com/tenant/chick-fil-a/
# https://www.netleaseadvisor.com/tenant/chipotle/
# https://www.netleaseadvisor.com/tenant/churchs-chicken/
# https://www.netleaseadvisor.com/tenant/dairy-queen/
# https://www.netleaseadvisor.com/tenant/dunkin-donuts/
# https://www.netleaseadvisor.com/tenant/hardees/
# https://www.netleaseadvisor.com/tenant/jack-in-the-box/
# https://www.netleaseadvisor.com/tenant/kfc/
# https://www.netleaseadvisor.com/tenant/mcdonalds/
# https://www.netleaseadvisor.com/tenant/panera-bread/
# https://www.netleaseadvisor.com/tenant/pdq/
# https://www.netleaseadvisor.com/tenant/pizza-hut/
# https://www.netleaseadvisor.com/tenant/pollo-tropical/
# https://www.netleaseadvisor.com/tenant/popeyes/
# https://www.netleaseadvisor.com/tenant/raising-canes/
# https://www.netleaseadvisor.com/tenant/sonic/
# https://www.netleaseadvisor.com/tenant/starbucks-coffee/
# https://www.netleaseadvisor.com/tenant/steak-n-shake/
# https://www.netleaseadvisor.com/tenant/taco-bell/
# https://www.netleaseadvisor.com/tenant/wendys/
# https://www.netleaseadvisor.com/tenant/zaxbys/

# %%
QSR_links
# Out:
# ['https://www.netleaseadvisor.com/tenant/arbys/',
#  'https://www.netleaseadvisor.com/tenant/bojangles/',
#  'https://www.netleaseadvisor.com/tenant/burger-king/',
#  'https://www.netleaseadvisor.com/tenant/captain-ds/',
#  'https://www.netleaseadvisor.com/tenant/chick-fil-a/',
#  'https://www.netleaseadvisor.com/tenant/chipotle/',
#  'https://www.netleaseadvisor.com/tenant/churchs-chicken/',
#  'https://www.netleaseadvisor.com/tenant/dairy-queen/',
#  'https://www.netleaseadvisor.com/tenant/dunkin-donuts/',
#  'https://www.netleaseadvisor.com/tenant/hardees/',
#  'https://www.netleaseadvisor.com/tenant/jack-in-the-box/',
#  'https://www.netleaseadvisor.com/tenant/kfc/',
#  'https://www.netleaseadvisor.com/tenant/mcdonalds/',
#  'https://www.netleaseadvisor.com/tenant/panera-bread/',
#  'https://www.netleaseadvisor.com/tenant/pdq/',
#  'https://www.netleaseadvisor.com/tenant/pizza-hut/',
#  'https://www.netleaseadvisor.com/tenant/pollo-tropical/',
#  'https://www.netleaseadvisor.com/tenant/popeyes/',
#  'https://www.netleaseadvisor.com/tenant/raising-canes/',
#  'https://www.netleaseadvisor.com/tenant/sonic/',
#  'https://www.netleaseadvisor.com/tenant/starbucks-coffee/',
#  'https://www.netleaseadvisor.com/tenant/steak-n-shake/',
#  'https://www.netleaseadvisor.com/tenant/taco-bell/',
#  'https://www.netleaseadvisor.com/tenant/wendys/',
#  'https://www.netleaseadvisor.com/tenant/zaxbys/']

# %%
QSR_links[1]
# Out:
# 'https://www.netleaseadvisor.com/tenant/bojangles/'

# %%
html2=uReq(QSR_links[1])

# %%
soup2=BeautifulSoup(html2,'lxml')

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Bojangles’ | Net Lease Advisor
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php" rel="pingback"/>
#   <script type="text/javascript">
#    var ajaxurl = 'https://www.netleaseadvisor.com/wp-admin/admin-ajax.php';
#   </script>
#   <!-- All in One SEO Pack 2.7.3 by Michael Torbert of Semper Fi Web Design[-1,-1] -->
#   <link href="https://www.netleaseadvisor.com/tenant/bojangles/" rel="canonical"/>
#   <!-- /all in one seo pack -->
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://www.netleaseadvisor.com/feed/" rel="alternate" title="Net Lease Advisor » Feed" type="application/rss+xml"/>
#   <link href="https://www.netleaseadvisor.com/comments/feed/" rel="alternate" title="Net Lease Advisor » Comments Feed" type="application/rss+xml"/>
#   <link href="https://www.netleaseadvisor.com/tenant/bojangles/feed/" rel="alternate" title="Net Lease Advisor » Bojangles’ Comments Feed" type="application/rss+xml"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.netleaseadvisor.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.css?ver=4.9.8" id="jquery-ui-timepicker-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/css/dsc-style.css?ver=4.9.8" id="dsc-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/css/settings.css?ver=5.3.0.2" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="rs-plugin-settings-inline-css" type="text/css">
#    #rs-demo-id {}
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.6-78496d1" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=4.9.8" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/bootstrap.min.css?ver=4.9.8" id="lambda-bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/theme.min.css?ver=4.9.8" id="lambda-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda-child-theme/style.css?ver=4.9.8" id="lambda-child-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/lambda/stack-90.css?ver=4.9.8" id="lambda-theme-stack-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/css/wpb_wmca_style.css?ver=1.0" id="wpb_wmca_accordion_style-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="//www.google.com/jsapi?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/js/dynamic-stock-charts.min.js?ver=1.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.tools.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.revolution.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var mejsL10n = {"language":"en","strings":{"mejs.install-flash":"You are using a browser that does not have Flash player enabled or installed. Please turn on your Flash player plugin or download the latest version from https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen-off":"Turn off Fullscreen","mejs.fullscreen-on":"Go Fullscreen","mejs.download-video":"Download Video","mejs.fullscreen":"Fullscreen","mejs.time-jump-forward":["Jump forward 1 second","Jump forward %1 seconds"],"mejs.loop":"Toggle Loop","mejs.play":"Play","mejs.pause":"Pause","mejs.close":"Close","mejs.time-slider":"Time Slider","mejs.time-help-text":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.","mejs.time-skip-back":["Skip back 1 second","Skip back %1 seconds"],"mejs.captions-subtitles":"Captions\/Subtitles","mejs.captions-chapters":"Chapters","mejs.none":"None","mejs.mute-toggle":"Mute Toggle","mejs.volume-help-text":"Use Up\/Down Arrow keys to increase or decrease volume.","mejs.unmute":"Unmute","mejs.mute":"Mute","mejs.volume-slider":"Volume Slider","mejs.video-player":"Video Player","mejs.audio-player":"Audio Player","mejs.ad-skip":"Skip ad","mejs.ad-skip-info":["Skip in 1 second","Skip in %1 seconds"],"mejs.source-chooser":"Source Chooser","mejs.stop":"Stop","mejs.speed-rate":"Speed Rate","mejs.live-broadcast":"Live Broadcast","mejs.afrikaans":"Afrikaans","mejs.albanian":"Albanian","mejs.arabic":"Arabic","mejs.belarusian":"Belarusian","mejs.bulgarian":"Bulgarian","mejs.catalan":"Catalan","mejs.chinese":"Chinese","mejs.chinese-simplified":"Chinese (Simplified)","mejs.chinese-traditional":"Chinese (Traditional)","mejs.croatian":"Croatian","mejs.czech":"Czech","mejs.danish":"Danish","mejs.dutch":"Dutch","mejs.english":"English","mejs.estonian":"Estonian","mejs.filipino":"Filipino","mejs.finnish":"Finnish","mejs.french":"French","mejs.galician":"Galician","mejs.german":"German","mejs.greek":"Greek","mejs.haitian-creole":"Haitian Creole","mejs.hebrew":"Hebrew","mejs.hindi":"Hindi","mejs.hungarian":"Hungarian","mejs.icelandic":"Icelandic","mejs.indonesian":"Indonesian","mejs.irish":"Irish","mejs.italian":"Italian","mejs.japanese":"Japanese","mejs.korean":"Korean","mejs.latvian":"Latvian","mejs.lithuanian":"Lithuanian","mejs.macedonian":"Macedonian","mejs.malay":"Malay","mejs.maltese":"Maltese","mejs.norwegian":"Norwegian","mejs.persian":"Persian","mejs.polish":"Polish","mejs.portuguese":"Portuguese","mejs.romanian":"Romanian","mejs.russian":"Russian","mejs.serbian":"Serbian","mejs.slovak":"Slovak","mejs.slovenian":"Slovenian","mejs.spanish":"Spanish","mejs.swahili":"Swahili","mejs.swedish":"Swedish","mejs.tagalog":"Tagalog","mejs.thai":"Thai","mejs.turkish":"Turkish","mejs.ukrainian":"Ukrainian","mejs.vietnamese":"Vietnamese","mejs.welsh":"Welsh","mejs.yiddish":"Yiddish"}};
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.6-78496d1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/Chart.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <link href="https://www.netleaseadvisor.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <link href="https://www.netleaseadvisor.com/tenant/bbt-bank/" rel="prev" title="BB&amp;T Bank"/>
#   <link href="https://www.netleaseadvisor.com/tenant/burger-king/" rel="next" title="Burger King"/>
#   <meta content="WordPress 4.9.8" name="generator"/>
#   <link href="https://www.netleaseadvisor.com/?p=450" rel="shortlink"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fbojangles%2F" rel="alternate" type="application/json+oembed"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fbojangles%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#   <!-- This site is using AdRotate v4.14 Professional to display their advertisements - https://ajdg.solutions/products/adrotate-for-wordpress/ -->
#   <style type="text/css">
#    .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#   </style>
#   <meta content="Powered by Visual Composer - drag and drop page builder for WordPress." name="generator"/>
#   <!--[if lte IE 9]><link rel="stylesheet" type="text/css" href="https://www.netleaseadvisor.com/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css" media="screen"><![endif]-->
#   <!--[if lte IE 8]><script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/excanvas.compiled.js"></script><![endif]-->
#   <style>
#    /*wp_charts_js responsive canvas CSS override*/
#     			.wp_charts_canvas {
#     				width:100%!important;
#     				max-width:100%;
#     			}
#
#     			@media screen and (max-width:480px) {
#     				div.wp-chart-wrap {
#     					width:100%!important;
#     					float: none!important;
# 						margin-left: auto!important;
# 						margin-right: auto!important;
# 						text-align: center;
#     				}
#     			}
#   </style>
#   <meta content="Powered by Slider Revolution 5.3.0.2 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-150x150.png" rel="icon" sizes="32x32"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="icon" sizes="192x192"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" name="msapplication-TileImage"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto:100,300,300italic,400,400italic,500,700,700italic%7CRoboto+Condensed:300,400,700%7CCutive:400%7CRoboto+Slab:100,300,400,700&amp;subset=latin,latin,latin,latin" rel="stylesheet" type="text/css"/>
#   <style media="screen" type="text/css">
#    .tenant-news-title {
#     font-family: Roboto, sans-serif;
#     font-weight: bold;
#     line-height: 18px;
#     margin-bottom: -4px;
# }
# span.tenant-news-date {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# span.tenant-news-source {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# .eh-section {
#   margin-top: -15px;
# }
# .eh-title {
#     font-size: 18px;
#     font-weight: bold;
#     color: #FF6D00;
#     margin-top: -5px;
#     margin-bottom: 11px;
#     line-height: 20px;
# }
# .eh-bullets {
#  padding-bottom: 10px;
# }
# .eh-buttons a i {
#     margin-left: 0px !important;
#     padding-right: 5px !important;
#     font-size: 18px;
#     position: relative;
#     top: 1px;
# }
#
# .eh-buttons a {
# background: #9c0 !important;
# font-weight: bold;
# margin-top: -3px;
# }
# .eh-buttons a:hover {
# background: #ff6d00 !important;
# }
#
# /* Sidebar Contact Us button hover fix */
# .sidebar-contact-btn.btn.btn-block.btn-success:hover {
#     background-color: #ff6d00 !important;
# }
# /* SCUBHF END */
#
# /* Sector Button Hover Fix */
# .selector-buttons:hover {
#     background-color: #ff6d00;
# }
# /* SBHF END */
#
# /* Credit Rating Nav item fix */
# .menu-item-523.active a:hover, .current-menu-item.menu-item-523 a:hover {
#     color: #0a2341 !important;
# }
# .menu-item-523.active a, .current-menu-item.menu-item-523 a{
#     color: #FFFFFF !important;
# }
# /* CRNIF END */
# .powered-by {
#   margin-top: -15px;
# }
#
# .dsc-loader {
#
#     position: relative !important;
#     top: 140px !important;
#
# }
#
# .wpcf7-mail-sent-ok {
#  color: #07182d !important;
#  font-weight: bold !important;
# font-size: 18px !important;
# }
#
# .btn {
#   border-radius: 5px !important;
# }
#
# .tenant-snapshot {
# 	color: #9c0;
# 	font-size: 22px;
#         line-height: 38px;
# 	margin-top: 4px;
# 	margin-bottom: -1px;
#
# }
#
# .tenant-snapshot .tenant-name {
# 	color: #0a2341;
# 	font-size: 40px;
# 	/* position: relative;
#         top: 6px; */
# }
#
# @media (max-width: 700px) {
#
# .tenant-logo {
#     height: 75px !important;
#     width: 100% !important;
#     margin-bottom: 25px !important;
# }
# .tenant-logo img {
#     position: inherit !important;
# }
#
# }
#
# /* Stock Chart Tooltip Style */
# .google-visualization-tooltip .dsc-tooltip caption {
#     font-size: 18px;
#     padding: 0;
# }
# .google-visualization-tooltip .dsc-tooltip td.label {
#     width: auto;
#     color: #FF6D00;
#     text-align: right;
#     padding-right: 5px;
# }
#
# /* Site Width Settings */
# @media (min-width: 1200px) and (max-width: 1414px){
#      .container {
#         width: 1200px !important;
#     }
#
# .featured-thumb a img {
#     width: 65px;
# }
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 17px;
#     font-weight: bold;
#     color: #84919F;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-desc {
#     float: left;
#     margin-left: 10px;
#     line-height: 18px;
# }
# }
#
# @media (min-width: 1415px){
#     .container {
#         width: 1400px !important;
#     }
# }
# @media (min-width: 768px){
#     .container {
#         width: 100%;
#     }
# }
# a.tenant-detail-link.btn.btn-success, .sidebar-contact-btn {
#     background: #9c0 !important;
#     border-radius: 5px !important;
#     font-size: 20px;
#     padding: 7px 30px;
#     margin: 20px auto;
#     font-weight: bold;
#     text-transform: uppercase;
# }
# a.tenant-detail-link.btn.btn-success:hover, .sidebar-contact-btn:hover {
#     background-color: #83ad04 !important;
# }
# .table-striped > tbody > tr:nth-child(odd) > td, .table-striped > tbody > tr:nth-child(odd) > th, .table-hover > tbody > tr:hover > td, .table-hover > tbody > tr:hover > th {
#     background: rgb(243, 243, 243);
# }
#
# section.section.tenant > .container > .row {
#     padding-bottom: 30px;
# }
#
# /* HOMEPAGE FEATURED TENANTS */
#
# .featured-single-wrapper {
#     width: 100%;
#     margin-top: 10px;
#     margin-bottom: 10px;
# }
#
# .featured-thumb {
#     float: left;
# }
#
# .featured-thumb a img {
#     width: 65px;
# }
#
# .featured-desc {
#     float: left;
#     margin-left: 15px;
#     line-height: 18px;
# }
#
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 20px;
#     font-weight: bold;
#     color: #84919F;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-tenants > .post-title {
#     padding-top: 30px;
# }
#
# .featured-sector, .featured-cap {
#     font-size: 14px;
# }
#
# .featured-sector span, .featured-cap span {
#     font-weight: bold;
# }
#
# /* HEADER TAGLINE */
#
# .tagline {
# 	font-family: "Roboto Condensed" !important;
# 	font-weight: bold !important;
# 	font-size: 20px !important;
# 	color: #fff !important;
#         text-align: right !important;
# }
#
# /* SIDEBAR ACCORDION */
#
# .selector-buttons {
#     width: 100%;
#     margin: 30px 0;
#     padding: 10px;
#     font-size: 18px;
#     font-weight: bold;
#     background-color: #9c0;
# }
#
# @media (min-width: 992px) and (max-width: 1199px){
#
#     .selector-buttons {
#         font-size: 16px;
#         padding: 10px 5px;
#     }
#
# }
#
# .sidebar-toggle {
#     display:none;
# }
#
# @media (max-width: 991px) {
#     .col-md-3.sidebar .sidebar-collapse-control-btn {
#         position: absolute;
#         top: -1px;
#         left: -55px;
#         width: 55px;
#         height: 45px;
#         background-color: #9c0;
#         border-top-left-radius: 5px;
#         border-bottom-left-radius: 5px;
#     }
#     .sidebar-collapse-control-btn button.navbar-toggle.collapsed {
#         margin: 14px 15px;
#     }
#     .col-md-3.sidebar {
#         position: absolute;
#         top: -65px;
#         right: -300px;
#         width: 300px;
#         background-color: #f3f3f3;
#         border: 1px solid #9c0;
#     }
#
#
# .sidebar-toggle {
#     display: block;
#     background: none !important;
#     margin: 14px 17px;
#     width: 22px;
#     height: 16px;
#     border: none;
#     transform: translate3d(0,0,0);
# }
#
# .sidebar-toggle .icon-bar:nth-child(1) {
#     top: 0;
# }
#
# .sidebar-toggle .icon-bar {
#     background-color: #fff;
# }
#
# .sidebar-toggle .icon-bar {
#     height: 1px;
#     width: 100%;
#     position: absolute;
#     left: 0;
#     margin-top: 0!important;
#     transition: all .3s;
#     -ms-transform-origin: 50% 50% 50%;
#     transform-origin: 50% 50% 50%;
#     transform: translate3d(0,0,0);
#     box-shadow: none;
# }
#
# .sidebar-toggle .icon-bar {
#     display: block;
#     width: 22px;
#     height: 1px;
#     border-radius: 1px;
# }
#
# .sidebar-toggle .icon-bar:nth-child(3) {
#     top: 100%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(2) {
#     opacity: 0;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(1) {
#     -ms-transform: rotate(45deg);
#     transform: rotate(45deg);
#     top: 50%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(3) {
#     top: 50%;
#     -ms-transform: rotate(-45deg);
#     transform: rotate(-45deg);
# }
#
# [class*="col-"].sidebar {
#     margin-bottom: auto !important;
#     padding-bottom: 0 !important;
# }
#
# .selector-buttons:hover {
#     background-color: #83ad04;
# }
# }
#
# .ui-accordion h3 {
#    margin-top: 0;
#     margin-bottom: 0px;
#     padding-top: 1px;
#     padding-bottom: 1px;
#     padding-left: 3px;
# }
# .ui-accordion h3:hover {
#     background-color: #FF6D00;
#     color: #FFFFFF;
#     cursor: pointer;
# }
# li.accordion-list-item {
#     list-style: none;
#     border-bottom: 1px solid #84919f;
#     margin-left: 0px;
#     padding-left: 5px;
# }
# a li.accordion-list-item {
#     font-size: 16px;
# }
#
# li.accordion-list-item:hover {
#     background-color: #FF6D00;
#     color: #FFF;
#     cursor: pointer;
# }
#
# a li.accordion-list-item:hover {
#     color: #0a2341;
#     cursor: pointer;
# }
#
# li.accordion-list-item.active-tenant {
#     background-color: #9c0;
#     padding-left: 5px;
#     margin-left: 0px;
# }
#
# a li.accordion-list-item.active-tenant {
#     color: #FFF;
# }
#
# /* AD AREAS */
# .banner-ad-wrapper {
#     padding: 50px 0;
#     text-align: center;
# }
#
# h3.sidebar-header {
#     text-transform: initial;
#     font-size: 24px;
#     border-bottom: 1px solid #84919f;
#     margin-bottom: 1px;
# }
# ul.tenant-list-ucr {
#     list-style: none;
#     padding: 0px;
#     margin: 0px;
# }
# li.tlucr-item {
#     border-bottom: 1px solid #84919f;
#     margin-left: 5px;
#     font-size: 16px;
# }
# .squeeze {
#     line-height: 1.5em !important;
# }
# /* SINGLE TENANT PAGE */
#
# .sidebar {
#     background-color: rgba(234, 233, 233, 0.55);
# }
#
# .tenant h1.post-title {
#     font-size: 35px;
#     font-weight: bold;
#     margin-top: 0px;
# }
#
# .header-updated-hr {
#     border-color: #9c0;
#     margin: -10px 0 3px;
# }
# .tenant-logo-home {
#     right: 15px;
#     top: 4px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# .tenant-logo {
#     right: 15px;
#     top: 8px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# @media (max-width: 991px){
#     .tenant-logo {
#         margin-right: 55px;
#     }
# }
# @media (max-width: 1414px){
#  .tenant h1.post-title {
#     font-size: 26px;
#     font-weight: bold;
#     margin-top: 40px;
# }
# }
# .tenant-logo  img {
#     max-width: 100%;
#     position: absolute;
#     bottom: 0;
#     right: 0;
# }
# .detail-box .detail-head {
#     background-color: #0a2341;
#     color: #fff;
#     text-transform: normal;
#     font-size: 18px;
#     padding: 2px 10px;
#     text-align: right;
#     font-weight: 400;
# }
# .detail-large-data {
#     text-align: right;
#     font-size: 78px;
#     line-height: 85px;
#     font-weight: bold;
#     color: #FF6D00;
# }
# .detail-sm-desc {
#     font-size: 13px;
#     text-align: right;
#     clear: both;
# }
# .detail-box {
#     margin-bottom: 25px;
# }
# .detail-data-table tr td {
#     padding-top: 5px !important;
#     padding-bottom: 5px !important;
# }
# .tenant-url-link {
#     margin-bottom: 15px;
# }
# .tenant-url-link a {
#     color: #FF6D00;
#     font-size: 16px;
#     font-weight: bold;
# }
# .tenant-url-link a:hover {
#     text-decoration: underline;
# }
# .tenant-stock-chart {
#     margin: 15px 0 30px;
#     margin-top: -20px;
# }
# .dschart {
#       margin-top: -20px;
# }
# td.data-label {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#     font-weight: 400;
#     line-height: 18px !important;
# }
# td.data-data {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#    font-weight: 400;
#     line-height: 18px !important;
# }
#
# .credit-rating td.data-label, .credit-rating td.data-data {
#     line-height: 22px !important;
#     width: 50%;
#     text-align: right;
#     font-size: 36px;
#     font-weight: bold;
#     color: #FF6D00;
#     padding: 10px 0 !important;
#  }
# .pros > h3, .cons > h3 {
#    padding-left: 11px;
# }
# .pro-item, .con-item, .eh-item {
#      font-size: 16px;
#      line-height: 20px;
#      margin-bottom: .8em;
# }
# .trend-info {
#     width: 33%;
#     float: left;
#     text-align: center;
#     margin-top: 8px;
# }
# .trend-year {
#     font-size: 18px;
#     color: #0a2341;
#     margin-top: -15px;
# }
# .trend-rate {
#     font-size: 28px;
#     font-weight: bold;
#     color: #0a2341;
# }
# .trend-image {
# width: 34%;
#     float: left;
#     text-align: center;
# }
# .tenant-description p {
#     font-size: 16px;
# }
# .tenant-description a {
# color: #FF6D00;
# }
# li.accordion-list-item.active {
#     background-color: #ff6d00;
# }
# li.accordion-list-item.active a {
#     color: #FFF;
# }
#
# /* MODAL */
# .modal-title {
#      font-size: 24px;
#      line-height: 24px;
# }
# .modal-body {
#     font-size: 14px;
#     line-height: 18px;
# }
# .modal-body a {
#     color: #99cc00;
# }
# .modal-header {
#     border-bottom: 1px solid #99cc00;
# }
# /* NET LEASE 101 */
# .caption-text {
# 	font-size: 16px;
# 	line-height: 1.4em;
# }
# .caption-head {
# 	font-family: Roboto Condensed, sans-serif;
# 	font-size: 21px;
# 	font-weight: bold;
# 	color: #0a2341;
# }
#
# /*OTHER*/
# i {
#   color: #9c0 !important;
# }
# .post-date {
#     font-size: 12px !important;
#     position: relative;
#     top: -2px !important;
#     font-style: italic;
#     color: #8e8e8e;
#     text-align: right;
# }
#
# #footer {
#   font-size: 14px;
# }
# .row:not(.sidebar-row){
#     overflow: hidden;
# }
#
# [class*="col-"].sidebar{
#     margin-bottom: -99999px;
#     padding-bottom: 99999px;
# }
#
# .subfooter {
#   text-align: center;
#   font-weight: 300;
# }
# .subfooter a {
#   font-weight: 400;
# }
#   </style>
#   <noscript>
#    <style type="text/css">
#     .wpb_animate_when_almost_visible { opacity: 1; }
#    </style>
#   </noscript>
#  </head>
#  <body class="tenant-template-default single single-tenant postid-450 wpb-js-composer js-comp-ver-5.0 vc_responsive">
#   <div class="pace-overlay">
#   </div>
#   <div class="menu navbar navbar-static-top header-logo-left-menu-below oxy-mega-menu navbar-sticky navbar-not-mobile-stuck text-none" id="masthead" role="banner">
#    <div class="logo-navbar container-logo">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle collapsed" data-target=".main-navbar" data-toggle="collapse" type="button">
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a class="navbar-brand" href="https://www.netleaseadvisor.com">
#        <img alt="Net Lease Advisor" src="https://netleaseadvisor.com/wp-content/uploads/2017/02/Net-Lease-Advisor-Logo-03.png"/>
#       </a>
#       <div class="logo-sidebar">
#        <div class="sidebar-widget widget_text" id="text-7">
#         <div class="textwidget">
#          <div class="powered-by">
#           Powered by
#          </div>
#          <div>
#           <a href="http://www.calkain.com" target="_new">
#            <img src="https://netleaseadvisor.com/wp-content/uploads/2017/02/Calkain-logo-white-200w.png" width="110px"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="nav-container clearfix">
#      <nav class="collapse navbar-collapse main-navbar navbar-left" role="navigation">
#       <div class="menu-container">
#        <ul class="nav navbar-nav" id="menu-main">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-66" id="menu-item-66">
#          <a href="https://www.netleaseadvisor.com/">
#           HOME
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-728" id="menu-item-728">
#          <a href="https://www.netleaseadvisor.com/net-lease-101/">
#           NET LEASE 101
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-523" id="menu-item-523">
#          <a data-target="#521" data-toggle="modal" href="#">
#           CREDIT RATINGS
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-518" id="menu-item-518">
#          <a href="https://www.netleaseadvisor.com/contact/">
#           CONTACT
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="menu-sidebar">
#       </div>
#      </nav>
#     </div>
#    </div>
#   </div>
#   <div id="content" role="main">
#    <section class="section tenant">
#     <div class="container">
#      <div class="row">
#       <div class="col-md-9">
#        <p style="height: 45px;">
#        </p>
#        <article class="post-450 tenant type-tenant status-publish has-post-thumbnail hentry sector-qsr" id="post-450">
#         <h1 class="post-title">
#          Bojangles’ TENANT OVERVIEW
#         </h1>
#         <div class="tenant-logo">
#          <img src="https://www.netleaseadvisor.com/wp-content/uploads/2016/09/t47logo.png"/>
#         </div>
#         <hr class="header-updated-hr"/>
#         <div class="post-date">
#          Updated: February 21, 2018
#         </div>
#         <div class="row">
#          <div class="col-md-8">
#           <div class="figure fade-in text-center figcaption-middle">
#            <img alt="" class="attachment-large size-large wp-post-image" height="364" sizes="(max-width: 800px) 100vw, 800px" src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/bojangles-calkain-800x364.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/bojangles-calkain-800x364.jpg 800w, https://www.netleaseadvisor.com/wp-content/uploads/2017/02/bojangles-calkain-300x136.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2017/02/bojangles-calkain-768x349.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2017/02/bojangles-calkain.jpg 1100w" width="800"/>
#           </div>
#           <div class="pros_cons row">
#            <div class="pros col-md-6">
#             <h3>
#              Pros
#             </h3>
#             <ul class="pros-list">
#              <li class="pro-item">
#               NNN lease eliminate landlord responsibilities
#              </li>
#              <li class="pro-item">
#               Average unit volumes for the chicken-and-biscuit concept continue increasing
#              </li>
#              <li class="pro-item">
#               Long-term growth plan to have 1,000 units open by 2020
#              </li>
#             </ul>
#            </div>
#            <div class="cons col-md-6">
#             <h3>
#              Cons
#             </h3>
#             <ul class="cons-list">
#              <li class="con-item">
#               No credit rating
#              </li>
#              <li class="con-item">
#               Tough competition
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="eh-section">
#            <h2>
#             Earnings Highlights
#            </h2>
#            <div class="eh-title">
#             Fiscal Year 2017 and Q4 Summary
#            </div>
#            <div class="eh-bullets">
#             <ul class="eh-list">
#              <li class="eh-item">
#               Q4 2017: Total revenues increased 6.2% from the prior year fiscal quarter, system-wide comparable restaurant sales decreased 3.1%
#              </li>
#              <li class="eh-item">
#               Fiscal Year 2017: Total revenues increased 2.9% from the prior fiscal year, system-wide comparable restaurant sales decreased 2.1%, and 52 restaurants were opened.
#              </li>
#             </ul>
#            </div>
#            <div class="eh-buttons">
#             <a class="btn btn-success eh_btn_1" href="http://investing.bojangles.com/phoenix.zhtml?c=253968&amp;p=irol-newsArticle&amp;ID=2336595" target="_blank">
#              <i aria-hidden="true" class="fa fa-newspaper-o">
#              </i>
#              Read Press Release
#             </a>
#            </div>
#           </div>
#           <div class="tenant-description">
#            <h2>
#             Tenant Description
#            </h2>
#            <p>
#             Bojangles’ is a quick-service restaurant based on distinctive flavor, high-quality products made-from-scratch, and a festive restaurant design with friendly service.
#             <br/>
#             <br/>
#             Bojangles' is a publicly traded company with a huge demand in the net lease world. The chain boasts 23 consecutive quarters of store sale growth and ranks top 5 for Fast Food by Zagat among large chains. Their freestanding stores features a 3,500 - 3,800 square foot building, and are usually situated on .8 - 1.50 acre of land. Bojangles' net leases properties provide a long-term investment with zero landlord responsibilities. Generally, the lease term is a 15-year NNN lease with 2-4 five (5) year options with increases of 7-10% every five (5) years. Some leases have an annual rental bumps ranging between 1.25% - 1.5%.
#             <br/>
#             <br/>
#             Bojangles' is a highly differentiated and growing restaurant operator and franchisor dedicated to serving customers high-quality food made from Southern recipes. Since their founding in Charlotte, North Carolina in 1977, their core menu centered on "chicken 'n biscuits" has remained largely unchanged. Bojangles has become an iconic brand with a cult-like following due to their famous, made-from-scratch biscuits baked every 20 minutes, their fresh, never-frozen bone-in fried chicken and their famous iced tea.
#             <br/>
#             <br/>
#             Bojangles' went public in May 2015 on the NASDAQ and have since expanded to over 700 restaurants. There are 309 company-operated restaurants and 407 franchised restaurants located in eleven states, including North Carolina, South Carolina, Georgia, Virginia, Tennessee, Alabama, Maryland, Florida, Kentucky, West Virginia and Pennsylvania, and the District of Columbia. Bojangles’ continues to grow, targeting the mid-south as an “area of opportunity”.
#             <br/>
#             <br/>
#             A typical Bojangles' restaurant is a modern, freestanding building, which is approximately 3,800 square feet in size and can seat approximately 70 customers. The restaurant locations are typically free standing urban or suburban locations, and are located on approximately one acre of land and include a drive-thru window and approximately 45 parking spaces. The development cost to build a Bojangles' restaurant requires an average investment of approximately $2.2 million. This cost  includes: $0.6 million for land, approximately $1.3 million for the building construction, includes the building and site and soft costs, and approximately $0.3 million for equipment. , Bojangles’ primarily utilizes build-to-suit developments and equipment financing leases for their new company-operated restaurants, requiring minimal upfront cash investment. Each new restaurant under a build-to-suit development and equipment-financing lease typically requires an upfront cash equipment investment of approximately $85,000, and they target a year one cash-on-cash return of approximately 129%.
#            </p>
#           </div>
#           <div class="tenant-url-link">
#            <a href="http://www.bojangles.com" target="_blank">
#             www.bojangles.com
#            </a>
#           </div>
#           <!-- TradingView Widget BEGIN -->
#           <script src="https://s3.tradingview.com/tv.js" type="text/javascript">
#           </script>
#           <script type="text/javascript">
#            new TradingView.widget({
#   "width": 665,
#   "height": 400,
#   "symbol": "BOJA",
#   "interval": "W",
#   "timezone": "America/New_York",
#   "theme": "Light",
#   "style": "2",
#   "locale": "en",
#   "toolbar_bg": "rgba(255, 109, 0, 1)",
#   "enable_publishing": false,
#   "withdateranges": true,
#   "allow_symbol_change": true,
#   "details": true,
#   "hideideas": true
# });
#           </script>
#           <!-- TradingView Widget END -->
#          </div>
#          <div class="col-md-4">
#           <div class="detail-box">
#            <div class="detail-head">
#             Average Cap Rate
#            </div>
#            <div class="detail-large-data">
#             6.12%
#            </div>
#            <div class="detail-sm-desc">
#             12 mo avg with 10+ yr lease term
#            </div>
#           </div>
#           <div class="detail-box average-property-lease">
#            <div class="detail-head">
#             Average Property &amp; Lease
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                Average Sale Price
#               </td>
#               <td class="data-data">
#                $2,413,908
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                NOI
#               </td>
#               <td class="data-data">
#                $147,731
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                $/Square Foot
#               </td>
#               <td class="data-data">
#                $650 - $700
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Building SF
#               </td>
#               <td class="data-data">
#                3,500 - 3,800
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lot Size
#               </td>
#               <td class="data-data">
#                0.8 - 1.5 Acres
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lease Term
#               </td>
#               <td class="data-data">
#                15 Years
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Escalations
#               </td>
#               <td class="data-data">
#                Varies
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Stock Symbol
#               </td>
#               <td class="data-data">
#                BOJA
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="detail-box credit-rating">
#            <div class="detail-head">
#             Credit Rating
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                S&amp;P
#               </td>
#               <td class="data-data">
#                N/A
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Moody's
#               </td>
#               <td class="data-data">
#                N/A
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc" style="font-style: italic;">
#            </div>
#           </div>
#           <div class="detail-box average-cap-rate-trend">
#            <div class="detail-head">
#             Average Cap Rate Trend
#            </div>
#            <div class="cap-rate-trend-continer">
#             <div class="trend-info">
#              <div class="trend-left">
#               <div class="trend-rate">
#                6.19%
#               </div>
#               <div class="trend-year">
#                2016
#               </div>
#              </div>
#             </div>
#             <div class="trend-image">
#              <img src="/wp-content/plugins/post-accordion-widget-plugin/images/down.png"/>
#             </div>
#             <div class="trend-info">
#              <div class="trend-right">
#               <div class="trend-rate">
#                6.13%
#               </div>
#               <div class="trend-year">
#                2017
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="detail-sm-desc" style="padding-top: 5px;">
#             Rates reflect last 12 mos, short and long-term
#            </div>
#           </div>
#           <div class="detail-box recent-sales-comps">
#            <div class="detail-head">
#             Recent Sales Comps
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Irmo, SC
#               </td>
#               <td class="data-data">
#                5.85%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Lumberton, NC
#               </td>
#               <td class="data-data">
#                7.00%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Morrow, GA
#               </td>
#               <td class="data-data">
#                6.58%
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc">
#            </div>
#           </div>
#           <div class="detail-box tenant-news">
#            <div class="detail-head">
#             Tenant News
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td>
#                <a href="https://www.qsrmagazine.com/news/bojangles-eyes-expansion-midwest-and-south" target="_blank">
#                 <div class="news-single-wrapper">
#                  <div class="tenant-news-title">
#                   Bojangles' Eyes Expansion in the Midwest and South
#                  </div>
#                  <div class="tenant-news-subtitle">
#                   <span class="tenant-news-date">
#                    November 10, 2017
#                   </span>
#                   -
#                   <span class="tenant-news-source">
#                    QSR Magazine
#                   </span>
#                  </div>
#                  <div class="clearfix">
#                  </div>
#                 </div>
#                </a>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="https://www.modernrestaurantmanagement.com/the-future-is-here-now-at-bojangles/" target="_blank">
#                 <div class="news-single-wrapper">
#                  <div class="tenant-news-title">
#                   The Future Is Here Now at Bojangles
#                  </div>
#                  <div class="tenant-news-subtitle">
#                   <span class="tenant-news-date">
#                    March 19, 2018
#                   </span>
#                   -
#                   <span class="tenant-news-source">
#                    Modern Restaurant Management
#                   </span>
#                  </div>
#                  <div class="clearfix">
#                  </div>
#                 </div>
#                </a>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="https://www.qsrmagazine.com/news/bojangles-unveils-expansion-plans-north-florida" target="_blank">
#                 <div class="news-single-wrapper">
#                  <div class="tenant-news-title">
#                   Bojangles' Unveils Expansion Plans for North Florida
#                  </div>
#                  <div class="tenant-news-subtitle">
#                   <span class="tenant-news-date">
#                    August 18, 2017
#                   </span>
#                   -
#                   <span class="tenant-news-source">
#                    QSR Magazine
#                   </span>
#                  </div>
#                  <div class="clearfix">
#                  </div>
#                 </div>
#                </a>
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="detail-box featured-net-lease-listing">
#            <div class="detail-head">
#             Featured Tenant Profiles
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/sheetz/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/12/sheetz-exterior-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/sheetz/">
#                Sheetz
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Convenience Store
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                5.19%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/rite-aid/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/rite-aid-rome-ga-calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/rite-aid/">
#                Rite Aid
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Pharmacy
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                6.37%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/Oreilly-oakland-park-fl-calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#                O’Reilly Auto Parts
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Automotive
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                5.66%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </article>
#       </div>
#       <div class="col-md-3 sidebar">
#        <div class="sidebar-widget tax_accordion_widget_class" id="tax_accordion_widget-2">
#         <div class="sidebar-collapse-control-btn">
#          <button class="sidebar-toggle offscreen" type="button">
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="container-fluid">
#          <div class="row">
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-sector">
#             SECTOR
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-alpha">
#             A-Z
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="accordion-sector" id="accordion-sector" style="display:none;">
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Automotive
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#             Advance Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/autozone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/autozone/">
#             AutoZone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bridgestone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bridgestone/">
#             Bridgestone/Firestone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
# ...
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/sherwin-williams/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sherwin-williams/">
#             Sherwin-Williams
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/sonic/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/sonic/">
#             Sonic
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/starbucks-coffee/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/starbucks-coffee/">
#             Starbucks
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/steak-n-shake/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/steak-n-shake/">
#             Steak ‘n Shake
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/suntrust/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">
#             SunTrust
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           T
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/taco-bell/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/taco-bell/">
#             Taco Bell
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/td-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">
#             TD Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/the-learning-experience/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/the-learning-experience/">
#             The Learning Experience
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#             Tractor Supply Co.
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           V
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/verizon/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/verizon/">
#             Verizon Wireless
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           W
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/walgreens/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walgreens/">
#             Walgreens
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/walmart/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">
#             Walmart
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wawa/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wawa/">
#             Wawa
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wegmans/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wegmans/">
#             Wegmans
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wendys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wendys/">
#             Wendy’s
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Z
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/zaxbys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/zaxbys/">
#             Zaxby’s
#            </li>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-10">
#         <div class="textwidget">
#          <a href="/bov-request">
#           <img src="https://netleaseadvisor.com/wp-content/uploads/2017/06/ad-calkain-bov.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-8">
#         <h3 class="sidebar-header">
#          Understanding Credit Ratings
#         </h3>
#         <div class="textwidget">
#          <ul class="tenant-list-ucr">
#           <li class="tlucr-item">
#            <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#             View Credit Rating Chart
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="http://www.spratings.com/en_US/understanding-ratings" target="_new">
#             Standard &amp; Poors
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="https://www.moodys.com/Pages/amr002002.aspx" target="_new">
#             Moody's
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-9">
#         <h3 class="sidebar-header">
#          Have a Research Project?
#         </h3>
#         <div class="textwidget">
#          <div class="squeeze">
#           Our experienced team provides unique insight to the net lease industry.  We can provide an in-depth analysis to a specific segment or assess an investment on your behalf.  Let us know your needs.
#          </div>
#          <a href="/contact">
#           <div class="sidebar-contact-btn btn btn-block btn-success">
#            Contact Us
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <footer id="footer" role="contentinfo">
#     <section class="section">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-6">
#          <div class="textwidget">
#           All logos are ©Copyright, ®Registered Trademarks and courtesy of their respective companies, and are displayed in this website for the sole purpose of brand recognition in tenant labeling.
#           <br/>
#           ©2017-2018 netleaseadvisor.com,
#           <a href="http://calkain.com" target="_new">
#            Calkain Companies LLC
#           </a>
#           . All Rights Reserved.
#           <br/>
#           12930 Worldgate Drive, Suite 150 | Herndon, VA 20170 |
#  Tel: (703) 787-4714
#           <br/>
#           <span style="color:#a0a0a0; font-weight:bold;">
#            Developed by
#           </span>
#           <a href="mailto:mjvdesign@gmail.com?subject=Ref: netleaseadvisor.com">
#            <img alt="MJVdesign" border="0" src="/wp-content/uploads/2017/03/mjvdesign_logo_transp_light.png" style="margin-top: 2px; margin-left: -4px;" title="Email MJVdesign"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="section subfooter">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-11">
#          <div class="textwidget">
#           <a href="https://www.netleaseadvisor.com">
#            Home
#           </a>
#           |
#           <a href="/net-lease-101">
#            Net Lease 101
#           </a>
#           |
#           <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#            Credit Rating Chart
#           </a>
#           |
#           <a href="/contact">
#            Contact
#           </a>
#           |
#           <a href="/bov-request">
#            BOV Request
#           </a>
#           |
#           <a href="https://calkain.com">
#            Calkain.com
#           </a>
#           |
#           <a href="https://calkain.com/research">
#            Calkain Research
#           </a>
#           |
#           <a href="https://calkain.com/properties">
#            Calkain Properties
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </footer>
#   </div>
#   <!-- Fixing the Back to top button -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   ga('create', 'UA-4933828-6', 'auto');
#
#   ga('send', 'pageview');
#   </script>
#   <div class="modal fade" id="40" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        Subscribe
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        [mc4wp_form]
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="521" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-lg" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CREDIT RATING CHART
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        <img alt="Net Lease Advisor Credit Rating Chart" class="alignnone wp-image-1087 size-full" height="883" sizes="(max-width: 900px) 100vw, 900px" src="https://netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg 900w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-300x294.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-768x753.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-800x785.jpg 800w" width="900"/>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="516" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CONTACT
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        For specific inquiries regarding this website or tenant information, please contact:
#       </p>
#       <p>
#        <strong>
#         Vinky Marolia
#        </strong>
#        <br/>
#        Research Analyst, Calkain Companies
#        <br/>
#        (571) 449-8146
#        <br/>
#        <a href="mailto:research@calkain.com">
#         research@calkain.com
#        </a>
#       </p>
#       <p>
#        For general inquiries or phone numbers and addresses for all of our office locations:
#        <br/>
#        <a href="http://calkain.com/contact/" target="_blank">
#         Contact Calkain
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/accordion.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/post-accordion-widget-plugin/controller.js?ver=9.9" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var click_object = {"ajax_url":"https:\/\/www.netleaseadvisor.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/adrotate-pro/library/jquery.adrotate.clicktracker.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.netleaseadvisor.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.0.3" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/slider.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/button.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-sliderAccess.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.cookie.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.navgoco.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var oxyThemeData = {"navbarScrolledPoint":"30","navbarHeight":"100","navbarScrolled":"50","siteLoader":"off","menuClose":"off","scrollFinishedMessage":"No more items to load.","hoverMenu":{"hoverActive":true,"hoverDelay":200,"hoverFadeDelay":200}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/js/theme.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts//js/functions.js?ver=4.9.8" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/wp-embed.min.js?ver=4.9.8" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
def Average_Cap_Rate(soup):
    return soup.find(string='Average Cap Rate').findNext('div').get_text()

# %%
Average_Cap_Rate(soup2)
# Out:
# '6.12%'

# %%
def Average_Sale_Price(soup):
    return soup.find(string='Average Sale Price').findNext('td').get_text()

# %%
Average_Sale_Price(soup2)
# Out:
# '$2,413,908'

# %%
def NOI_f(soup):
    return soup.find(string='NOI').findNext('td').get_text()

# %%
NOI_f(soup2)
# Out:
# '$147,731'

# %%
def d_Square_Foot(soup):
    return soup.find(string='$/Square Foot').findNext('td').get_text()

# %%
d_Square_Foot(soup2)
# Out:
# '$650 - $700'

# %%
def Building_SF(soup):
    return soup.find(string='Building SF').findNext('td').get_text()

# %%
Building_SF(soup2)
# Out:
# '3,500 - 3,800'

# %%
def Lot_Size(soup):
    return soup.find(string='Building SF').findNext('td').get_text()

# %%
Lot_Size(soup2)
# Out:
# '3,500 - 3,800'

# %%
def Lease_Term(soup):
    return soup.find(string='Lease Term').findNext('td').get_text()

# %%
Lease_Term(soup2)
# Out:
# '15 Years'

# %%
def Escalations_f(soup):
    return soup.find(string='Escalations').findNext('td').get_text()

# %%
Escalations_f(soup2)
# Out:
# 'Varies'

# %%
def Stock_Symbol(soup):
    return soup.find(string='Stock Symbol').findNext('td').get_text()

# %%
Stock_Symbol(soup2)
# Out:
# 'BOJA'

# %%
def S_P(soup):
    return soup.find(string='S&P').findNext('td').get_text()

# %%
S_P(soup2)
# Out:
# 'N/A'

# %%
def Moodys_f(soup):
    return soup.find(string='Moody\'s').findNext('td').get_text()

# %%
Moodys_f(soup2)
# Out:
# 'N/A'

# %%
def Trend_1Y(soup):
    return soup.findAll('div',{'class':'trend-rate'})[0].get_text()

# %%
Trend_1Y(soup2)
# Out:
# '6.19%'

# %%
def Trend_2Y(soup):
    return soup.findAll('div',{'class':'trend-rate'})[1].get_text()

# %%
Trend_2Y(soup2)
# Out:
# '6.13%'

# %%
QSR_links
# Out:
# ['https://www.netleaseadvisor.com/tenant/arbys/',
#  'https://www.netleaseadvisor.com/tenant/bojangles/',
#  'https://www.netleaseadvisor.com/tenant/burger-king/',
#  'https://www.netleaseadvisor.com/tenant/captain-ds/',
#  'https://www.netleaseadvisor.com/tenant/chick-fil-a/',
#  'https://www.netleaseadvisor.com/tenant/chipotle/',
#  'https://www.netleaseadvisor.com/tenant/churchs-chicken/',
#  'https://www.netleaseadvisor.com/tenant/dairy-queen/',
#  'https://www.netleaseadvisor.com/tenant/dunkin-donuts/',
#  'https://www.netleaseadvisor.com/tenant/hardees/',
#  'https://www.netleaseadvisor.com/tenant/jack-in-the-box/',
#  'https://www.netleaseadvisor.com/tenant/kfc/',
#  'https://www.netleaseadvisor.com/tenant/mcdonalds/',
#  'https://www.netleaseadvisor.com/tenant/panera-bread/',
#  'https://www.netleaseadvisor.com/tenant/pdq/',
#  'https://www.netleaseadvisor.com/tenant/pizza-hut/',
#  'https://www.netleaseadvisor.com/tenant/pollo-tropical/',
#  'https://www.netleaseadvisor.com/tenant/popeyes/',
#  'https://www.netleaseadvisor.com/tenant/raising-canes/',
#  'https://www.netleaseadvisor.com/tenant/sonic/',
#  'https://www.netleaseadvisor.com/tenant/starbucks-coffee/',
#  'https://www.netleaseadvisor.com/tenant/steak-n-shake/',
#  'https://www.netleaseadvisor.com/tenant/taco-bell/',
#  'https://www.netleaseadvisor.com/tenant/wendys/',
#  'https://www.netleaseadvisor.com/tenant/zaxbys/']

# %%
AverageCapRates=[]
AverageSalePrices=[]
NOI=[]
DollarSquareFoot=[]
BuildingSF=[]
LotSize=[]
LeaseTerm=[]
Escalations=[]
StockSymbol=[]
SP=[]
Moodys=[]
Trend1Y=[]
Trend2Y=[]

# %%
def QSR_f(links):
    for link in links:
        html=uReq(link)
        soup=BeautifulSoup(html,'lxml')
        AverageCapRates.append(Average_Cap_Rate(soup))
        AverageSalePrices.append(Average_Sale_Price(soup))
        NOI.append(NOI_f(soup))
        DollarSquareFoot.append(d_Square_Foot(soup))
        BuildingSF.append(Building_SF(soup))
        LotSize.append(Lot_Size(soup))
        LeaseTerm.append(Lease_Term(soup))
        Escalations.append(Escalations_f(soup))
        StockSymbol.append(Stock_Symbol(soup))
        SP.append(S_P(soup))
        Moodys.append(Moodys_f(soup))
        Trend1Y.append(Trend_1Y(soup))
        Trend2Y.append(Trend_2Y(soup))

# %%
QSR_f(QSR_links)

# %%
QSR_df=pd.DataFrame({'Average Cap Rates' : AverageCapRates,
 'Average Sale Prices' : AverageSalePrices,
 'NOI':NOI,'$/Square Foot' : DollarSquareFoot,
 'Building SF' : BuildingSF,
 'Lot Size':LotSize,'Lease Term' : LeaseTerm,
 'Escalations' : Escalations,
 'Stock Symbol':StockSymbol,'S&P' : SP,
 'Moodys' : Moodys,
 'Trend1Y':Trend1Y,'Trend2Y':Trend2Y,'QSR_links':QSR_links
  })

# %%
QSR_df
# Out:
#    Average Cap Rates Average Sale Prices       NOI    $/Square Foot  \
# 0              5.94%          $1,534,323   $91,139      $450 - $625
# 1              6.12%          $2,413,908  $147,731      $650 - $700
# 2              5.62%          $1,897,695  $163,650             $520
# 3              6.37%          $1,237,250   $78,813             $450
# 4              4.41%          $2,837,917  $125,152             $680
# 5              4.85%          $1,884,700   $91,408      $550 - $950
# 6              6.20%          $1,786,667  $110,773    $500 - $1,000
# 7              6.13%          $1,720,433  $105,463             $600
# 8              5.52%          $1,699,312   $92,146             $785
# 9              5.85%          $1,866,731  $109,204      $400 - $600
# 10             5.20%          $2,538,257  $131,989             $840
# 11             6.04%          $1,197,841   $72,350      $400 - $600
# 12             4.20%          $1,885,007   $79,170             $490
# 13             5.07%          $2,964,491  $150,300      $600 - $750
# 14             5.67%          $3,328,757  $188,741             $830
# 15             6.30%          $1,077,040   $67,854      $375 - $925
# 16             4.87%          $2,786,561  $135,706    $750 - $1,000
# 17             5.44%          $2,089,169  $113,651    $700 - $1,000
# 18             5.66%          $4,194,355  $237,400  $1,200 - $1,700
# 19             6.15%          $1,521,055   $93,545           $1,014
# 20             4.92%          $2,282,377  $112,293  $1,100 - $1,500
# 21             6.20%          $2,540,500  $157,511             $675
# 22             5.17%          $2,201,996  $113,843   $1,000- $1,200
# 23             5.33%          $2,211,683  $117,883             $735
# 24             6.46%          $3,043,912  $196,637       $750- $875
#
#        Building SF        Lot Size     Lease Term  \
# 0    2,500 - 3,500   2,500 - 3,500       20 Years
# 1    3,500 - 3,800   3,500 - 3,800       15 Years
# 2            3,500           3,500  10 - 20 Years
# 3    2,400 - 3,400   2,400 - 3,400       15 Years
# 4            4,500           4,500       20 Years
# 5    2,000 - 3,500   2,000 - 3,500   10 - 15 Year
# 6     1,700 -3,500    1,700 -3,500       20 Years
# 7            2,800           2,800       20 Years
# 8            2,200           2,200  15 - 20 Years
# 9   2,5000 - 3,500  2,5000 - 3,500  15 - 20 Years
# 10           2,500           2,500       20 Years
# 11   2,000 - 3,000   2,000 - 3,000       15 Years
# 12           4,500           4,500        20 Year
# 13   4,000 - 5,000   4,000 - 5,000       15 Years
# 14           4,000           4,000  15 - 20 Years
# 15   1,150 - 2,900   1,150 - 2,900  10 - 15 Years
# 16   2,800 - 3,700   2,800 - 3,700  15 - 20 Years
# 17   2,000 - 3,000   2,000 - 3,000  15 - 20 Years
# 18   2,500 - 3,500   2,500 - 3,500  15 - 20 Years
# 19           1,500           1,500  15 - 20 Years
# 20   1,500 - 2,000   1,500 - 2,000       10 Years
# 21           3,700           3,700       20 Years
# 22   1,800 - 2,200   1,800 - 2,200       20 Years
# 23           3,000           3,000       20 Years
# 24   3,000 - 4,000   3,000 - 4,000       15 Years
#
#                                Escalations Stock Symbol   S&P Moodys Trend1Y  \
# 0                                   Varies          N/A   N/A    N/A   6.41%
# 1                                   Varies         BOJA   N/A    N/A   6.19%
# 2                       7.5% Every 5 Years          QSR    B+    N/A   6.13%
# 3                                   Varies          N/A   N/A    N/A   6.87%
# 4              10% Every 5 Years & Options          N/A   N/A    N/A   4.18%
# 5                  7.5 - 12% Every 5 Years          CMG   N/A    N/A   4.87%
# 6       10% Every 5 Years or 1.5% Annually          N/A   N/A    N/A   6.60%
# 7   1.5-2% Annually or 8-10% Every 5 Years        BRK.A    AA    Aa2   6.36%
# 8                      8-10% Every 5 Years         DNKN   N/A    N/A   5.58%
# 9                    5 - 10% Every 5 Years          N/A    B-    N/A   5.98%
# 10                   5 - 10% Every 5 Years         JACK   N/A    N/A   5.63%
# 11                                  Varies          YUM    BB    Ba3   5.98%
# 12                       10% Every 5 Years          MCD  BBB+   Baa1   4.54%
# 13                                  Varies         PNRA   N/A    N/A   5.29%
# 14                       10% Every 5 Years          N/A   N/A    N/A   5.79%
# 15                                  Varies          YUM    BB    Ba3   6.48%
# 16                                  Varies          N/A   N/A    N/A   4.93%
# 17                                  Varies          QSR    B+    N/A   5.33%
# 18                   5 - 10% Every 5 Years          N/A   N/A    N/A   5.88%
# 19                                  Varies         SONC   N/A    N/A   6.50%
# 20                       10% Every 5 Years         SBUX    A-     A3   5.23%
# 21                       10% Every 5 Years           BH    B-     B3   6.13%
# 22                                  Varies          YUM    BB    Ba3   5.54%
# 23                   5 - 10% Every 5 Years          WEN     B     B2   5.74%
# 24                                  Varies          N/A   N/A    N/A   6.61%
#
#    Trend2Y                                          QSR_links
# 0    6.05%      https://www.netleaseadvisor.com/tenant/arbys/
# 1    6.13%  https://www.netleaseadvisor.com/tenant/bojangles/
# 2    5.87%  https://www.netleaseadvisor.com/tenant/burger-...
# 3    7.24%  https://www.netleaseadvisor.com/tenant/captain...
# 4    4.53%  https://www.netleaseadvisor.com/tenant/chick-f...
# 5    5.37%   https://www.netleaseadvisor.com/tenant/chipotle/
# 6    6.91%  https://www.netleaseadvisor.com/tenant/churchs...
# 7    5.92%  https://www.netleaseadvisor.com/tenant/dairy-q...
# 8    5.37%  https://www.netleaseadvisor.com/tenant/dunkin-...
# 9    6.15%    https://www.netleaseadvisor.com/tenant/hardees/
# 10   5.12%  https://www.netleaseadvisor.com/tenant/jack-in...
# 11   6.75%        https://www.netleaseadvisor.com/tenant/kfc/
# 12   4.37%  https://www.netleaseadvisor.com/tenant/mcdonalds/
# 13   5.01%  https://www.netleaseadvisor.com/tenant/panera-...
# 14   5.67%        https://www.netleaseadvisor.com/tenant/pdq/
# 15   6.65%  https://www.netleaseadvisor.com/tenant/pizza-hut/
# 16   4.87%  https://www.netleaseadvisor.com/tenant/pollo-t...
# 17   5.51%    https://www.netleaseadvisor.com/tenant/popeyes/
# 18   5.36%  https://www.netleaseadvisor.com/tenant/raising...
# 19   6.16%      https://www.netleaseadvisor.com/tenant/sonic/
# 20   4.97%  https://www.netleaseadvisor.com/tenant/starbuc...
# 21   6.40%  https://www.netleaseadvisor.com/tenant/steak-n...
# 22   5.42%  https://www.netleaseadvisor.com/tenant/taco-bell/
# 23   5.63%     https://www.netleaseadvisor.com/tenant/wendys/
# 24   6.35%     https://www.netleaseadvisor.com/tenant/zaxbys/

# %%
QSR_df.to_csv('QSR.csv', sep=',')
